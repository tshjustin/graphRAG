# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.indexer_adapters import (
    read_indexer_covariates,
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.input.loaders.dfs import (
    store_entity_semantic_embeddings,
)
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.embedding import OpenAIEmbedding
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.local_search.mixed_context import (
    LocalSearchMixedContext,
)
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore

# %% [markdown]
# ### Load text units and graph data tables as context for local search
#
# - In this test we first load indexing outputs from parquet files to dataframes, then convert these dataframes into collections of data objects aligning with the knowledge model.

# %% [markdown]
# ### Load tables to dataframes

# %%
INPUT_DIR = "/home/tjustin/ragtest/output/20240806-152635/artifacts"
LANCEDB_URI = f"{INPUT_DIR}/lancedb"

COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
RELATIONSHIP_TABLE = "create_final_relationships"
COVARIATE_TABLE = "create_final_covariates"
TEXT_UNIT_TABLE = "create_final_text_units"
COMMUNITY_LEVEL = 2

# %%
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")

entity_df
# Out:
#        level                    title          type  \
# 0          0                  ISWARAN        PERSON
# 1          0                SINGAPORE      LOCATION
# 2          0       PRIME MINISTER LEE        PERSON
# 3          0       TRANSPORT MINISTER      POSITION
# 4          0                  S$8,500         MONEY
# ...      ...                      ...           ...
# 83885      4      FIXIE-RELATED SALES
# 83886      4               ROAD BIKES       PRODUCT
# 83887      4           YEE QING XIANG        PERSON
# 83888      4  CYCLING INTEREST GROUPS         GROUP
# 83889      4           BIKE RETAILERS  ORGANIZATION
#
#                                              description  \
# 0      Iswaran, also known as S Iswaran, is a governm...
# 1      Singapore is a country in Southeast Asia known...
# 2      Lee Hsien Loong is the Prime Minister of Singa...
# 3      The Transport Minister, held by Iswaran, is a ...
# 4      "S$8,500" refers to the reduced pay that Minis...
# ...                                                  ...
# 83885
# 83886  Road bikes are a type of bike that customers h...
# 83887      Yee Qing Xiang is the founder of Ascent Bikes
# 83888  Cycling interest groups are organizations that...
# 83889  Bike retailers are businesses that LTA has rea...
#
#                                                source_id community  degree  \
# 0      0cb5774a229508e0d84bbfce11de09f6,12960edd561d1...        18      18
# 1      003814c7c2f12401d9706d441d0d78b8,0078cd13d70e1...         2     611
# 2      466696ce9a54965230df4c5b61560fb8,5d4ff31938b3a...        39       2
# 3      0cb5774a229508e0d84bbfce11de09f6,466696ce9a549...        18       1
# 4      466696ce9a54965230df4c5b61560fb8,92d27d8aef2b9...        18       1
# ...                                                  ...       ...     ...
# 83885                   2f94dbbdc8787a2c83dc611a0c9be630      None       1
# 83886                   fee73eba470e6edec8b7cb3363199217      None       1
# 83887                   fee73eba470e6edec8b7cb3363199217      None       1
# 83888                   fee73eba470e6edec8b7cb3363199217      None       1
# 83889                   fee73eba470e6edec8b7cb3363199217      None       1
#
#        human_readable_id                                id  size  \
# 0                      0  b45241d70f0e43fca764df95b2b81f77    18
# 1                      1  4119fd06010c494caa07f439b333f4c5   611
# 2                      2  d3835bf3dda84ead99deadbeac5d0d7d     2
# 3                      3  077d2820ae1845bcbb1803379a3d1eae     1
# 4                      4  3671ea0dd4e84c1a9b02c5ab2c8f4bac     1
# ...                  ...                               ...   ...
# 83885              16773  799ad1424d854025905279f3781b53b5     1
# 83886              16774  4be6b48107f848fe901659703b2dd8e3     1
# 83887              16775  ec11badacafd451aa68fa03b79218d0c     1
# 83888              16776  e350ee63f47245d5b4ca2d98627b7c8c     1
# 83889              16777  dd12c83cce5840b7948f3ecdfbbb5fb8     1
#
#       graph_embedding entity_type                 top_level_node_id  x  y
# 0                None        None  b45241d70f0e43fca764df95b2b81f77  0  0
# 1                None        None  4119fd06010c494caa07f439b333f4c5  0  0
# 2                None        None  d3835bf3dda84ead99deadbeac5d0d7d  0  0
# 3                None        None  077d2820ae1845bcbb1803379a3d1eae  0  0
# 4                None        None  3671ea0dd4e84c1a9b02c5ab2c8f4bac  0  0
# ...               ...         ...                               ... .. ..
# 83885            None        None  799ad1424d854025905279f3781b53b5  0  0
# 83886            None        None  4be6b48107f848fe901659703b2dd8e3  0  0
# 83887            None        None  ec11badacafd451aa68fa03b79218d0c  0  0
# 83888            None        None  e350ee63f47245d5b4ca2d98627b7c8c  0  0
# 83889            None        None  dd12c83cce5840b7948f3ecdfbbb5fb8  0  0
#
# [83890 rows x 15 columns]

# %% [markdown]
# #### Read entities - embedding

# %%
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

entity_embedding_df
# Out:
#                                    id                     name          type  \
# 0    b45241d70f0e43fca764df95b2b81f77                  ISWARAN        PERSON
# 1    4119fd06010c494caa07f439b333f4c5                SINGAPORE      LOCATION
# 2    d3835bf3dda84ead99deadbeac5d0d7d       PRIME MINISTER LEE        PERSON
# 3    077d2820ae1845bcbb1803379a3d1eae       TRANSPORT MINISTER      POSITION
# 4    3671ea0dd4e84c1a9b02c5ab2c8f4bac                  S$8,500         MONEY
# ..                                ...                      ...           ...
# 241  799ad1424d854025905279f3781b53b5      FIXIE-RELATED SALES
# 242  4be6b48107f848fe901659703b2dd8e3               ROAD BIKES       PRODUCT
# 243  ec11badacafd451aa68fa03b79218d0c           YEE QING XIANG        PERSON
# 244  e350ee63f47245d5b4ca2d98627b7c8c  CYCLING INTEREST GROUPS         GROUP
# 245  dd12c83cce5840b7948f3ecdfbbb5fb8           BIKE RETAILERS  ORGANIZATION
#
#                                            description  human_readable_id  \
# 0    Iswaran, also known as S Iswaran, is a governm...                  0
# 1    Singapore is a country in Southeast Asia known...                  1
# 2    Lee Hsien Loong is the Prime Minister of Singa...                  2
# 3    The Transport Minister, held by Iswaran, is a ...                  3
# 4    "S$8,500" refers to the reduced pay that Minis...                  4
# ..                                                 ...                ...
# 241                                                                 16773
# 242  Road bikes are a type of bike that customers h...              16774
# 243      Yee Qing Xiang is the founder of Ascent Bikes              16775
# 244  Cycling interest groups are organizations that...              16776
# 245  Bike retailers are businesses that LTA has rea...              16777
#
#     graph_embedding                                      text_unit_ids  \
# 0              None  [0cb5774a229508e0d84bbfce11de09f6, 12960edd561...
# 1              None  [003814c7c2f12401d9706d441d0d78b8, 0078cd13d70...
# 2              None  [466696ce9a54965230df4c5b61560fb8, 5d4ff31938b...
# 3              None  [0cb5774a229508e0d84bbfce11de09f6, 466696ce9a5...
# 4              None  [466696ce9a54965230df4c5b61560fb8, 92d27d8aef2...
# ..              ...                                                ...
# 241            None                 [2f94dbbdc8787a2c83dc611a0c9be630]
# 242            None                 [fee73eba470e6edec8b7cb3363199217]
# 243            None                 [fee73eba470e6edec8b7cb3363199217]
# 244            None                 [fee73eba470e6edec8b7cb3363199217]
# 245            None                 [fee73eba470e6edec8b7cb3363199217]
#
#                                  description_embedding
# 0    [-0.034168317914009094, -0.01597527228295803, ...
# 1    [0.008972381241619587, 0.02507088892161846, 0....
# 2    [0.03169342130422592, -0.053404662758111954, 0...
# 3    [-0.021919820457696915, -0.020537102594971657,...
# 4    [-0.013535933569073677, 0.00680833263322711, 0...
# ..                                                 ...
# 241  [-0.006175657268613577, 0.005057513248175383, ...
# 242  [0.051137614995241165, 0.008133879862725735, -...
# 243  [0.0434858463704586, -0.015871243551373482, -0...
# 244  [-0.0134590370580554, 0.005320436786860228, 0....
# 245  [-0.008262849412858486, 0.045671526342630386, ...
#
# [16778 rows x 8 columns]

# %% [markdown]
# #### Read relationships

# %%
relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
relationships = read_indexer_relationships(relationship_df)

relationships
# Out:
# [Relationship(id='0fe3d521c2e0460ba18afb321887707f', short_id='0', source='ISWARAN', target='TRANSPORT MINISTER', weight=2.0, description='Iswaran, also known as the Transport Minister, holds the position in Singapore. Despite being interdicted from duty, Iswaran continues to serve as the Transport Minister in Singapore.', description_embedding=None, text_unit_ids=['0cb5774a229508e0d84bbfce11de09f6', '466696ce9a54965230df4c5b61560fb8'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='b33568f6b23f47cf8915d50e8cd71297', short_id='1', source='ISWARAN', target='CPIB', weight=8.0, description='The Corrupt Practices Investigation Bureau (CPIB) is conducting an investigation into Transport Minister S. Iswaran in a corruption case. Iswaran is actively assisting with the investigations related to this case, which also involves billionaire Ong Beng Seng.', description_embedding=None, text_unit_ids=['0cb5774a229508e0d84bbfce11de09f6', '12960edd561d130a4ca8b45ef2e5e5c4', '1ae4d1e68bd878571b4677342cbbf202', '466696ce9a54965230df4c5b61560fb8', '619b587fe3dd2cf7c03215f936675fc0', '6d4eb2bbd4a9f715ea55694b4a5d7963', '92d27d8aef2b98d001a1106a662c2f31', '9c71aa0dae4f7c1619fd8561d37612f9'], document_ids=None, attributes={'rank': 107}),
#  Relationship(id='2d7dafdbcbc844cc9142825085639ea5', short_id='2', source='ISWARAN', target='LEE', weight=1.0, description="Lee made the decision regarding Iswaran's situation as Prime Minister", description_embedding=None, text_unit_ids=['92d27d8aef2b98d001a1106a662c2f31'], document_ids=None, attributes={'rank': 49}),
#  Relationship(id='f6d269c6d2554f5e93eb866914fcc1fb', short_id='3', source='ISWARAN', target='PUBLIC SERVICE DIVISION', weight=1.0, description="Iswaran's case follows how the civil service would deal with a senior officer", description_embedding=None, text_unit_ids=['92d27d8aef2b98d001a1106a662c2f31'], document_ids=None, attributes={'rank': 24}),
#  Relationship(id='d3d67bc539c04851b12f25e9a33ff7f5', short_id='4', source='ISWARAN', target='MINISTER', weight=1.0, description='Iswaran is a political office holder under investigation', description_embedding=None, text_unit_ids=['92d27d8aef2b98d001a1106a662c2f31'], document_ids=None, attributes={'rank': 55}),
#  Relationship(id='ef38aa3f6957423d9558fe308e33de58', short_id='5', source='ISWARAN', target='S$8,500', weight=1.0, description="Iswaran's reduced pay is S$8,500", description_embedding=None, text_unit_ids=['92d27d8aef2b98d001a1106a662c2f31'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='36553828162a467a9675a3854fe4fadc', short_id='6', source='ISWARAN', target='15 PERCENT', weight=1.0, description="Iswaran's reduced pay is about 15 percent of the benchmark", description_embedding=None, text_unit_ids=['92d27d8aef2b98d001a1106a662c2f31'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='b5604c3201cc4503868de9f332e927b7', short_id='7', source='ISWARAN', target='MP', weight=1.0, description='MPs like Iswaran are mentioned in the text', description_embedding=None, text_unit_ids=['a741151b42fd7469135a2e878306a4f7'], document_ids=None, attributes={'rank': 45}),
#  Relationship(id='19f01ac9a8d74f719f38fa1160f7032d', short_id='8', source='ISWARAN', target='PUBLIC SERVICE', weight=1.0, description='Iswaran is a government official involved in the public service sector', description_embedding=None, text_unit_ids=['0cb5774a229508e0d84bbfce11de09f6'], document_ids=None, attributes={'rank': 65}),
#  Relationship(id='0a88d64ede4c46c8aa5177426345bbc4', short_id='9', source='ISWARAN', target='PAP', weight=2.0, description="The investigation into ISWARAN may have implications for the ruling People's Action Party (PAP). This suggests a potential connection between ISWARAN and the PAP, indicating that ISWARAN is likely a member or affiliated with the political party. The outcome of the investigation could impact the reputation or stability of the PAP.", description_embedding=None, text_unit_ids=['619b587fe3dd2cf7c03215f936675fc0', '6d4eb2bbd4a9f715ea55694b4a5d7963'], document_ids=None, attributes={'rank': 75}),
#  Relationship(id='967af0e2f2ce40c985f4d89ef93a0db2', short_id='10', source='ISWARAN', target='LEE HSIEN LOONG', weight=2.0, description='Prime Minister Lee Hsien Loong instructed Iswaran to take a leave of absence.', description_embedding=None, text_unit_ids=['619b587fe3dd2cf7c03215f936675fc0', '6d4eb2bbd4a9f715ea55694b4a5d7963'], document_ids=None, attributes={'rank': 37}),
#  Relationship(id='d814ed6e0c2548c4816178693a4d1672', short_id='11', source='ISWARAN', target='ONG BENG SENG', weight=3.0, description='Iswaran and Ong Beng Seng were both arrested by the CPIB in connection to a corruption probe. The two individuals are linked through their involvement in the same investigation.', description_embedding=None, text_unit_ids=['251ac27599fe5832823dab37861d339f', '619b587fe3dd2cf7c03215f936675fc0', '6d4eb2bbd4a9f715ea55694b4a5d7963'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='175924e8d89647f882dcbcea0d3f4f9a', short_id='12', source='ISWARAN', target='MINISTERIAL DUTIES', weight=1.0, description='Iswaran has been relieved of his ministerial duties', description_embedding=None, text_unit_ids=['8f62cb60f8294dc4b2e99c4dec8feb84'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='4aacba6447474b60888a03b4f3a83d2d', short_id='13', source='ISWARAN', target='WEST COAST GRC', weight=2.0, description='Iswaran, the anchor minister, plays a significant role in West Coast GRC, which holds importance in the upcoming general election.', description_embedding=None, text_unit_ids=['8f49bc76bbd560e5e85239744f4a796c', 'ca23c0477d48a9a675855a17729da715'], document_ids=None, attributes={'rank': 23}),
#  Relationship(id='9046e136c3d840f9afadd9438e5b08a7', short_id='14', source='ISWARAN', target='CORRUPTION PROBE', weight=1.0, description="Iswaran's involvement in the corruption probe may affect his candidacy", description_embedding=None, text_unit_ids=['ca23c0477d48a9a675855a17729da715'], document_ids=None, attributes={'rank': 23}),
#  Relationship(id='66abd099050643f28595f17062c62e42', short_id='15', source='ISWARAN', target='NUS PROF TAN', weight=2.0, description="NUS Prof Tan has commented on the implications of ISWARAN's involvement in the probe, suggesting that suspicions may linger regarding ISWARAN's actions. This indicates that there may be ongoing scrutiny or doubt surrounding ISWARAN's role in the situation.", description_embedding=None, text_unit_ids=['1ae4d1e68bd878571b4677342cbbf202', 'ca23c0477d48a9a675855a17729da715'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='073eefe2f4894bd6adcce223a8b6d791', short_id='16', source='ISWARAN', target='CANDIDATE', weight=1.0, description="Iswaran's involvement in the probe may affect his candidacy", description_embedding=None, text_unit_ids=['1ae4d1e68bd878571b4677342cbbf202'], document_ids=None, attributes={'rank': 71}),
#  Relationship(id='7250506ecca340db87e99beddf73c3ad', short_id='17', source='ISWARAN', target='PUBLIC OPINION', weight=1.0, description='Public opinion may be influenced by suspicions surrounding Iswaran', description_embedding=None, text_unit_ids=['1ae4d1e68bd878571b4677342cbbf202'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='9003e806c95747b686c0c0e71ea3e023', short_id='18', source='SINGAPORE', target='MR NG', weight=12.0, description="Mr Ng, a candidate for the presidency in Singapore, is advocating for non-partisan candidacy and is relatively unknown in Singapore despite his contributions. He is associated with Singapore as the former chief investment officer of GIC and is being evaluated for a role related to safeguarding Singapore's past reserves. Mr Ng mentions serving the people of Singapore as a higher calling and wants to do something for the benefit of the country. Additionally, he has warned about the misuse of Singapore's reserves.", description_embedding=None, text_unit_ids=['0889a9ff3c4ee9eae27b015f6797df79', '1fe7ddec49ae764b1afbf78c909bd7e6', '47134bc252aa5e726a871525850c1cc9', '590401c84a4764de0424842c0af9f8ec', '59476627cc0cab281103bce22989fdf1', '6c53b4db7ae57770eb8a29804880eb5b', '7fbcd41bde0bebe16efb2c932b0e5e5b', '7fec9137e509e3e61b4519895f3984e4', '83a51063f1418a69eff50a06dcee5b9d', '92d8f30ccca82b25ec621c86a179ea0d', '9413b516f6ff9f12b39718b85fe48637', 'b2e6c6d7b1efd39c01b9ab867898531d'], document_ids=None, attributes={'rank': 978}),
#  Relationship(id='1f73f56b161745d9bc327a2d1b91287f', short_id='19', source='SINGAPORE', target='SUICIDES', weight=1.0, description='Suicides were reported in Singapore in 2022', description_embedding=None, text_unit_ids=['a4e4641638e98e6a5ad509022bf16333'], document_ids=None, attributes={'rank': 617}),
#  Relationship(id='bae6dd6771db4a3fa6a880d604bf3bf7', short_id='20', source='SINGAPORE', target='GEORGE GOH', weight=5.0, description='George Goh, a candidate for the Singapore presidency, has recently moved to Singapore and successfully submitted his eligibility papers. He is actively discussing the presidential candidacy requirements in Singapore, indicating his serious intent to run for office in the country.', description_embedding=None, text_unit_ids=['0d867dfb41e873dadacea8c061681b2a', '131319fc101b9f77b39177289fb8da6d', '80d0c766cadf062983dcc530159d188f', 'b76282edac66bcc098aafadba49826ce', 'c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 680}),
#  Relationship(id='789f3a6818e2489991b4b793ce2a93f3', short_id='21', source='SINGAPORE', target='PRESIDENTIAL ELECTION', weight=6.0, description='The Presidential Election is currently taking place in Singapore, where Singaporeans will head to the ballot box to participate.', description_embedding=None, text_unit_ids=['2d7132d240dba2916e7eef851577ff4c', '416e9e5bdda32a59849f08fe78a5d1df', '4affcd135f6488b3e40adfa65c164429', 'e41c5acf3101f894d09d86808e4499a7', 'f755264a49ca0036428971a01ef11d63'], document_ids=None, attributes={'rank': 752}),
#  Relationship(id='95a7dfd74918402da601cf16d99d03f9', short_id='22', source='SINGAPORE', target='LORRY', weight=1.0, description='The lorry was traveling along the Pan-Island Expressway in Singapore', description_embedding=None, text_unit_ids=['d5f62145edf3a1e75e70970b00ec61e2'], document_ids=None, attributes={'rank': 621}),
#  Relationship(id='a10e2004be5b4c2e87b34c676a45d4bd', short_id='23', source='SINGAPORE', target='PONGAL', weight=1.0, description='Pongal is celebrated worldwide by Tamils, including in Singapore', description_embedding=None, text_unit_ids=['bc4b1210904b1af00cf4b48557fa6a0a'], document_ids=None, attributes={'rank': 612}),
#  Relationship(id='3012acaaec78475faeb4184b3b5580ca', short_id='24', source='SINGAPORE', target='AVANDA', weight=1.0, description='Avanda received financial contributions to launch from government-linked firms in Singapore', description_embedding=None, text_unit_ids=['9413b516f6ff9f12b39718b85fe48637'], document_ids=None, attributes={'rank': 623}),
#  Relationship(id='70c7a89be05d4533af84bba88f9b212e', short_id='25', source='SINGAPORE', target='MR THARMAN', weight=23.0, description="Mr Tharman, a prominent figure in Singaporean politics, is actively involved in politics and finance in Singapore. He is a candidate for the next President of Singapore and is aiming to become the head of state. Despite being a non-Chinese candidate, he is expected to represent Singapore on the world stage and promote its interests abroad. His election is seen as a milestone in Singapore's evolution, reflecting his confidence in Singapore and its people. Overall, Mr Tharman's win is viewed as a positive sign for Singapore's political landscape, and he vows to represent Singapore and its societal goals if elected.", description_embedding=None, text_unit_ids=['0d91eb0b1b8d9614953416c8a9ea6cd8', '13caff68638e68546b735712429e6000', '1e75f0c254fec4259f59c4659a124044', '202e8878141800107c2d746e2d713c7a', '212d391ed691c366dc4d17cf82df3acb', '23bdaf475083cb17fd0392ad0717475f', '3ea5ea58c8bc60054889c62c4c20986f', '565bd3e13ed1c2baf2db0c596756f254', '6a3f32df9cb3cee0e93a93b8213f8f63', '7a0a4256cbce855593e637f2cffe8ad9', '7b3646292c539efc16776003b8168057', '7c4ea17dce2fea9e0f0d071a5c3e7fa3', '8af622e0679f3955fa908e5a0e57e130', '9619d632741f0cfb433c7f33a93d0bb6', '9c52a5116db28eee86c3a640323582cd', 'a6167d5e6f3615dbfd6e1988b7f4341b', 'afafeb7bc3059dadb6df9621d2287252', 'b3b75f9b7afd07d838477efdc06a8d3b', 'c4a1c92bee46ede9a174e8c16e0008ef', 'ca5a21a9bc08b61e0a16d281954929ce', 'cf718da77378d17a615be2ec62a43eee', 'd53bb6c39002b91b5a9c391bf482fde4', 'e8686cdd2ac8548bdd62964632b0dea9'], document_ids=None, attributes={'rank': 977}),
#  Relationship(id='7df7ba6f935247cfa931d1745b3ed774', short_id='26', source='SINGAPORE', target='SINGAPORE DEPOSIT INSURANCE CORPORATION', weight=1.0, description='The Singapore Deposit Insurance Corporation administers the deposit insurance scheme in Singapore', description_embedding=None, text_unit_ids=['8584ecdd9c0b4ad875184a99ff244203'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='70990ca80b7e42f9b9c4fb74e502bab3', short_id='27', source='SINGAPORE', target='PRIME MINISTER', weight=1.0, description='The text mentions the new Prime Minister of Singapore', description_embedding=None, text_unit_ids=['dcb17e72fcb01366b298f0c380b9861a'], document_ids=None, attributes={'rank': 664}),
#  Relationship(id='ec48a5608892404dbdd156f6e4b2cf6b', short_id='28', source='SINGAPORE', target='CATHAY CINEPLEX', weight=1.0, description='Cathay Cineplex operates in Singapore', description_embedding=None, text_unit_ids=['a8776d1090f68ad38003a848afba09b6'], document_ids=None, attributes={'rank': 620}),
#  Relationship(id='b6152b95169645739557ed9ce3225829', short_id='29', source='SINGAPORE', target='GROUP', weight=2.0, description='The Barramundi Group, a company operating in Singapore, has a strategic focus on right-sizing the cinema business within the country.', description_embedding=None, text_unit_ids=['de285658824317f9f3c4539df6e57d31', 'e30e99d2297ed01df9ddc5b4ede02f69'], document_ids=None, attributes={'rank': 630}),
#  Relationship(id='037c9c20cef048658fe5962160580ca7', short_id='30', source='SINGAPORE', target='TEMASEK TRUST-CDC LIFELONG LEARNING ENABLING FUND', weight=1.0, description='The Temasek Trust-CDC Lifelong Learning Enabling Fund provides financial support to adults with special needs in Singapore', description_embedding=None, text_unit_ids=['e97e1ce05bbb9d241bc0582da07b6d7b'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='eef4526b107245edbfe6a51d9faacf8d', short_id='31', source='SINGAPORE', target='MDM NG', weight=1.0, description='Mdm Ng is discussing the need for more support for adults with special needs in Singapore', description_embedding=None, text_unit_ids=['ecba7ce650ee58929cf092db2f70f956'], document_ids=None, attributes={'rank': 628}),
#  Relationship(id='c3ed8ae4c2a94ddaa741c01a6cde39c5', short_id='32', source='SINGAPORE', target='SUPPORT GROUPS', weight=1.0, description='Support groups for parents of children with disabilities are rare in Singapore', description_embedding=None, text_unit_ids=['da54507dd59269f6612ce2a7be5dda8e'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='a6882717759748d8b3d15973237516b5', short_id='33', source='SINGAPORE', target='MR TAN', weight=7.0, description='MR TAN, a candidate for the position of President in SINGAPORE, is actively addressing issues, reaching out to voters, and campaigning in the country. He has observed the rarity of support groups for parents with similar experiences in Singapore, indicating a focus on community and social issues within his campaign.', description_embedding=None, text_unit_ids=['2d1fa026649dc59fccc5e03a71a22fac', '447079a08a0ddea6c2ee6f620753b32c', '502445e61d6d967334a49db40afed08c', '666553c7e8175d22df2cffc5876d072b', '6ee528f89a14d1340fea812c9d2100ad', 'c4e0376b3c94fdafb2259d5332c22da8', 'ceb8ea92217cf8c33700decef3b1cf56'], document_ids=None, attributes={'rank': 881}),
#  Relationship(id='725e0b0b4a5d4bbca80b3f4ca8e1f1b1', short_id='34', source='SINGAPORE', target='CORE INFLATION', weight=3.0, description="SINGAPORE, a country in Southeast Asia, is known for reporting specific CORE INFLATION data. This data is crucial for understanding the country's economic health and stability. The core inflation rate in Singapore is closely monitored and analyzed to assess the impact of price changes on the overall economy.", description_embedding=None, text_unit_ids=['b04c4ace9c3aad4b5e7b073761a18a97', 'c09f24d269a3873d26f7639751e470fd', 'fd7ae7f804090421780ceb10090d8a2c'], document_ids=None, attributes={'rank': 639}),
#  Relationship(id='76bed0abac084db78ab3a38971c804c4', short_id='35', source='SINGAPORE', target='MONEY LAUNDERING PROBE', weight=1.0, description='The money laundering probe involving Bearbrick figures took place in Singapore', description_embedding=None, text_unit_ids=['516e54df132aa9527e8707922a8ea857'], document_ids=None, attributes={'rank': 619}),
#  Relationship(id='cb0b378ff3a541d6883290269527d7ac', short_id='36', source='SINGAPORE', target='GEORGIAN MEN', weight=2.0, description='The Georgian men traveled to Singapore with the intention of committing theft, and indeed carried out theft activities within the country.', description_embedding=None, text_unit_ids=['4f7ec2bc715f54c3cc6be8a99fd95161', 'eefb683c4442c66c3eb44004195a134f'], document_ids=None, attributes={'rank': 615}),
#  Relationship(id='c8518afedd154d19afb4a2d5841045d7', short_id='37', source='SINGAPORE', target='FOODPANDA', weight=5.0, description='SINGAPORE is a location where FOODPANDA, a food delivery platform, operates. Recently, FOODPANDA has made significant impacts on workers in Singapore, including job cuts and layoffs. Additionally, there are plans for FOODPANDA to sell its business in Singapore.', description_embedding=None, text_unit_ids=['21bb1d9f9aca7829e8239b61601e05f4', '45b334fe67f6c36fef64fae0827fa160', '4e5e07486f04ba896f86cb3b934f04e7', '8c5d89cfd95a3969d8e345abb48d7e9c', '94818ebffc4b0e1e3510e6270da57e7c'], document_ids=None, attributes={'rank': 624}),
#  Relationship(id='9ab7e803ea68490aa03d2409e73e91a4', short_id='38', source='SINGAPORE', target='JOB CUTS', weight=1.0, description='Job cuts affected staff in Singapore', description_embedding=None, text_unit_ids=['751b23b0ef2c7d508e1a0f13b2b8e1f0'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='892130c1db1540a69fca876128f6b220', short_id='39', source='SINGAPORE', target='BANKS', weight=3.0, description='The major banks in Singapore, a prominent financial hub, will start charging customers for issuing Singdollar cheques. This move reflects the location of major banks in Singapore and their impact on the local financial landscape.', description_embedding=None, text_unit_ids=['37c7ef22b078fd984c0a8cb69244891b', '4c5843f44033c7c4d3cbddfda1281b21', 'f8258211825d30702d4126c742a8f02a'], document_ids=None, attributes={'rank': 658}),
#  Relationship(id='0287bb7b751e4bd7bebeef543212a1cf', short_id='40', source='SINGAPORE', target='MAS', weight=2.0, description="SINGAPORE is a country that has benefited from the financial regulatory framework reformed by MAS. The expertise of MAS also provides insights into the workings of Singapore's national reserves.", description_embedding=None, text_unit_ids=['6e5d22e6c03d1df29777acfcfd5e4fdb', 'a3a7c492c64d434eeb62185e811e6c85'], document_ids=None, attributes={'rank': 733}),
#  Relationship(id='7673770d50234624924fb807ee385517', short_id='41', source='SINGAPORE', target='MR WEE', weight=1.0, description='Mr Wee had a celebration in Singapore to engage with his Peranakan heritage', description_embedding=None, text_unit_ids=['0e2d868e0c9e19e466d08227dd63d4bd'], document_ids=None, attributes={'rank': 618}),
#  Relationship(id='5d544ffaf72544db9a818bffa4628250', short_id='42', source='SINGAPORE', target='PERANAKAN HERITAGE', weight=1.0, description="Peranakan heritage adds vibrancy to Singapore's culture", description_embedding=None, text_unit_ids=['dda2091386988290ae0982b99866dab9'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='ef19d4b6a580468c92697319c3244c39', short_id='43', source='SINGAPORE', target='SEA BASS', weight=1.0, description='The fish virus outbreak affects sea bass farming in Singapore', description_embedding=None, text_unit_ids=['231dfbc8bb39a834b4be32c4b10b6ff8'], document_ids=None, attributes={'rank': 621}),
#  Relationship(id='687718abd6814547b832ca795b79635f', short_id='44', source='SINGAPORE', target='STRAITS TIMES', weight=1.0, description='The Straits Times reported on the fish virus outbreak in Singapore', description_embedding=None, text_unit_ids=['231dfbc8bb39a834b4be32c4b10b6ff8'], document_ids=None, attributes={'rank': 651}),
#  Relationship(id='39c46433ce15488fa7077e893541c7e1', short_id='45', source='SINGAPORE', target='JOHOR STRAIT', weight=1.0, description='The Johor Strait is a location where fish farms in Singapore are located', description_embedding=None, text_unit_ids=['231dfbc8bb39a834b4be32c4b10b6ff8'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='d22ef7694e594bb59ee44bd9091b6618', short_id='46', source='SINGAPORE', target='SOUTH-EAST ASIA', weight=2.0, description='The entity Singapore is a country located in Southeast Asia, and it is also perceived as a gateway to South-east Asia for expansion. This suggests that Singapore plays a significant role in the region as a hub for business and trade within South-east Asia.', description_embedding=None, text_unit_ids=['146f106fafe3d0b350abd0892a4a1266', '598e763bf844cbc2311e61778ea9553f'], document_ids=None, attributes={'rank': 627}),
#  Relationship(id='6e013c97dc134e198204fe52b6a92a7d', short_id='47', source='SINGAPORE', target='BARRAMUNDI GROUP', weight=1.0, description='Barramundi Group faced financial losses in Singapore', description_embedding=None, text_unit_ids=['3bf648de6198126a902f342eaaf90121'], document_ids=None, attributes={'rank': 642}),
#  Relationship(id='0e57263f024b4ce0920d22ae647f9549', short_id='48', source='SINGAPORE', target='AQUA-TECH CAPABILITIES', weight=1.0, description='Singapore operations focus on aqua-tech capabilities', description_embedding=None, text_unit_ids=['3bf648de6198126a902f342eaaf90121'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='936ed9ab853849d58203d5d2fd78da1b', short_id='49', source='SINGAPORE', target='VIRUS', weight=1.0, description="The virus is mentioned as having an impact on Singapore's 2030 goal", description_embedding=None, text_unit_ids=['81355de09bcfe6d976aa3d0eab6ed0c1'], document_ids=None, attributes={'rank': 616}),
#  Relationship(id='756829efe7c4469f8caceed9d6c24949', short_id='50', source='SINGAPORE', target='NON-RESIDENT AMBASSADOR', weight=1.0, description="The individual was appointed as Singapore's non-resident ambassador to Morocco", description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 616}),
#  Relationship(id='960088cb563f4eb3a9b60cb59efea1a5', short_id='51', source='SINGAPORE', target='ALII PALAU', weight=1.0, description='Alii Palau planned to operate flights between Palau and Singapore', description_embedding=None, text_unit_ids=['7f90a375f728d005fba9ef257e75c6a7'], document_ids=None, attributes={'rank': 615}),
#  Relationship(id='d4f275d74f074e0c88a416f72aaa3d95', short_id='52', source='SINGAPORE', target='OPEN SKIES AGREEMENT', weight=2.0, description='SINGAPORE, a country in Southeast Asia, signed an OPEN SKIES AGREEMENT with Palau in October 2022. This agreement allows for open and unrestricted air travel between the two countries, promoting tourism and economic growth.', description_embedding=None, text_unit_ids=['0b9ce0982489b1a4308df0df706157c1', '7f90a375f728d005fba9ef257e75c6a7'], document_ids=None, attributes={'rank': 612}),
#  Relationship(id='9a2d39541eb746dca691da0d23cd3bcf', short_id='53', source='SINGAPORE', target='TIMES', weight=1.0, description='Times reported on the commercial flight between Singapore and Palau', description_embedding=None, text_unit_ids=['0b9ce0982489b1a4308df0df706157c1'], document_ids=None, attributes={'rank': 612}),
#  Relationship(id='3eb3bfdeecec4091989f62884cac3ecf', short_id='54', source='SINGAPORE', target='PALAU', weight=1.0, description='There is a commercial flight scheduled between Singapore and Palau', description_embedding=None, text_unit_ids=['0b9ce0982489b1a4308df0df706157c1'], document_ids=None, attributes={'rank': 632}),
#  Relationship(id='a44dbace6f494aee864f67187d7435b0', short_id='55', source='SINGAPORE', target='AIRLINE', weight=1.0, description='Airlines may operate flights between Singapore and Palau', description_embedding=None, text_unit_ids=['0b9ce0982489b1a4308df0df706157c1'], document_ids=None, attributes={'rank': 619}),
#  Relationship(id='99e3343a7bb24fda8ed2397eebf9f839', short_id='56', source='SINGAPORE', target='GOVERNMENT', weight=5.0, description='The Government of Singapore plays a crucial role in representing and advancing the interests of the people of Singapore. Recently, the government passed legislation to combat cyber scams, demonstrating its commitment to maintaining integrity within the country. The system of governance in Singapore appears to be functioning effectively, with efforts focused on protecting the well-being of its citizens and ensuring the overall progress of the nation.', description_embedding=None, text_unit_ids=['1a2722af1dcbfb335afa81722c02be47', '8af622e0679f3955fa908e5a0e57e130', '9a60f4ab3f012582000c19ab6944c2ee', 'c73a748208fdbb025b40e98e8a7d9c72', 'dd5fe501b09dfa91e99e51ecd0f53fbb'], document_ids=None, attributes={'rank': 779}),
#  Relationship(id='87115b594be7465f83d726487857b85b', short_id='57', source='SINGAPORE', target='INTERNET SOCIETY', weight=1.0, description='The Internet Society has a chapter in Singapore', description_embedding=None, text_unit_ids=['6040e764bc100fe97a3b1683ba06a7b3'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='9fc99ca478464e149c1f086956228d43', short_id='58', source='SINGAPORE', target='FOOD CHARITIES', weight=1.0, description='Food charities operate in Singapore and are impacted by donation trends in the country', description_embedding=None, text_unit_ids=['918f6e0c97739d87dca447eaaf546953'], document_ids=None, attributes={'rank': 618}),
#  Relationship(id='be5588693abc4af8b45421cf2a582c8e', short_id='59', source='SINGAPORE', target='BANK DEBT SALES', weight=1.0, description="Bank debt sales are surging in Singapore's market", description_embedding=None, text_unit_ids=['e4044eec9318f43137c59924dd6a65eb'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='5026b6d96be6403599fc51d5fe40183a', short_id='60', source='SINGAPORE', target='HSBC', weight=3.0, description="SINGAPORE is a key location for HSBC, where the bank operates, raises funds, and utilizes as a launchpad for digital innovation. This partnership highlights the significance of Singapore in HSBC's operations and strategic initiatives.", description_embedding=None, text_unit_ids=['1b8b625057eda5f1a05c1a69f3cb7fa3', '3066abac804940b00fc5b279c6305834', '31127b5706729f3c4ef78a1b4ebdd670'], document_ids=None, attributes={'rank': 634}),
#  Relationship(id='b133d648d0a74ba186364d17753117b2', short_id='61', source='SINGAPORE', target='CREDIT AGRICOLE', weight=1.0, description='Credit Agricole sold notes in Singapore', description_embedding=None, text_unit_ids=['1b8b625057eda5f1a05c1a69f3cb7fa3'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='c88db238663c4635b7228ed6744879a5', short_id='62', source='SINGAPORE', target='LLOYDS', weight=1.0, description='Lloyds sold notes in Singapore', description_embedding=None, text_unit_ids=['1b8b625057eda5f1a05c1a69f3cb7fa3'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='1a28020693e74499bbdad3053467160c', short_id='63', source='SINGAPORE', target='NG', weight=2.0, description="SINGAPORE is the country where Mr. NG is motivated to run for office. NG's fiancee, Sybil Lau, gave up her Canadian citizenship to become a Singaporean, indicating a strong connection to SINGAPORE.", description_embedding=None, text_unit_ids=['43ee4a976053ebab5d27ed46fa171c4b', '8651a1657c619bf706235c5f4932b862'], document_ids=None, attributes={'rank': 713}),
#  Relationship(id='5b474daccb8342869d08cf2b46da00a0', short_id='64', source='SINGAPORE', target='SYBIL LAU', weight=2.0, description='SINGAPORE is a country where SYBIL LAU, a citizen who moved there 18 years ago, resides.', description_embedding=None, text_unit_ids=['055dc6644b41535f455dd8e7214d1a7a', '25c6ca2a2032d95c2845ca867b5c9fd0'], document_ids=None, attributes={'rank': 626}),
#  Relationship(id='f7840e12330a42ef9a3f76a7c9ae6ffa', short_id='65', source='SINGAPORE', target='MS SYBIL LAU', weight=1.0, description='Ms Sybil Lau moved to Singapore 18 years ago', description_embedding=None, text_unit_ids=['52745df95315880d301b24f9bac19e4d'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='ccea2b4687354f2bbda45d8516fcd170', short_id='66', source='SINGAPORE', target='WOKEISM', weight=1.0, description='Discussion on wokeism culture is happening in Singapore', description_embedding=None, text_unit_ids=['67b5a6cae056ef649c5352d92efad251'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='611836984c7142af931b1741e87e6296', short_id='67', source='SINGAPORE', target='THARMAN', weight=10.0, description="Tharman Shanmugaratnam, a prominent politician in Singapore, has a strong connection to the country. He has represented Singapore's interests in international organizations and is currently launching a presidential bid. Tharman has expressed faith in the Singapore system and is discussing improvements in Singapore's early years. Recently, he achieved victory in the election, solidifying his position as a potential candidate for the presidency.", description_embedding=None, text_unit_ids=['0befb5c34ad4d2e0f743a8302a3dd80f', '1cda85fe83e6bbdfa391844abcb1900f', '3133f9a767995463394b1f2958188e3d', '619b587fe3dd2cf7c03215f936675fc0', '711e792eeafbbf23474c0010d50192e6', '83e5e993969711fcf69e8a6b586ffd93', '9873ed7340b59b6bfba899eca274e8e0', 'aab1446f7cd97dbcedfe595c3f1214c3', 'ad320f24ceb4c36ecd9aa488ad7a88be', 'de8ecdf75671c8f04ca970739dc13c9f'], document_ids=None, attributes={'rank': 819}),
#  Relationship(id='4c3873370a774b62bef00f46d6171a65', short_id='68', source='SINGAPORE', target='PRESIDENTIAL CANDIDATES', weight=5.0, description="In Singapore, potential presidential candidates are actively considering running for office, discussing the considerations for unlocking the country's past reserves, and campaigning for the upcoming Presidential Election. Multiple candidates are vying for the position of President, indicating a competitive political landscape in the country.", description_embedding=None, text_unit_ids=['0f28789b09728aed7c9b650464dbc2db', '8395e9a59ab29af9a268ed79f0cba1cf', 'bf07be4a242fa7bfffd24c0addce5924', 'caf0be647d6970333774c9a2d70661dd', 'ec1d6b757d8305f8966f6394376ec7ac'], document_ids=None, attributes={'rank': 676}),
#  Relationship(id='47e6cfc65dde46489b2bef74affe1e73', short_id='69', source='SINGAPORE', target='DR TAN', weight=1.0, description="Dr. Tan's endorsement is related to the country of Singapore", description_embedding=None, text_unit_ids=['6ee528f89a14d1340fea812c9d2100ad'], document_ids=None, attributes={'rank': 661}),
#  Relationship(id='354b0bf2a8f746b5a1cd544a74c010ef', short_id='70', source='SINGAPORE', target='PSP', weight=2.0, description="The Progress Singapore Party (PSP) is a political party in Singapore. The party's decision not to endorse a candidate is related to the country of Singapore.", description_embedding=None, text_unit_ids=['447079a08a0ddea6c2ee6f620753b32c', '6ee528f89a14d1340fea812c9d2100ad'], document_ids=None, attributes={'rank': 637}),
#  Relationship(id='136e76683b564adbbd101be68e92bb6b', short_id='71', source='SINGAPORE', target='POLITICAL OBJECTIVE', weight=1.0, description='The political objective is to realize a progressive, compassionate, and inclusive Singapore', description_embedding=None, text_unit_ids=['0b418b699d70eed386bc6781ea4ec3ae'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='e4ec14329a87441cbd9044d773397861', short_id='72', source='SINGAPORE', target='BILL TURTLE', weight=1.0, description="Hawksbill turtles are found in Singapore's waters", description_embedding=None, text_unit_ids=['b28c1f762fd187b61031ae8ef828f263'], document_ids=None, attributes={'rank': 612}),
#  Relationship(id='b1802d3af3a3468aaa48a951a8cdbdaa', short_id='73', source='SINGAPORE', target='ANWAR', weight=2.0, description='ANWAR, a prominent figure, recently made an official visit to SINGAPORE where he had a meeting with the Singapore Prime Minister Lee Hsien Loong. This visit signifies a significant interaction between ANWAR and the leadership of SINGAPORE, highlighting the importance of their relationship.', description_embedding=None, text_unit_ids=['4dade6181ba43ac51465b4a21ab1be5d', '8751348d6e72b10bea51ef965c9a77ac'], document_ids=None, attributes={'rank': 625}),
#  Relationship(id='060014ec4a7f4528ae97e263ffc2843f', short_id='74', source='SINGAPORE', target='LEE HSIEN LOONG', weight=2.0, description='Lee Hsien Loong is the Prime Minister of Singapore', description_embedding=None, text_unit_ids=['4dade6181ba43ac51465b4a21ab1be5d', '8420932a78c9cbb2a4bf3e26f4033a02'], document_ids=None, attributes={'rank': 630}),
#  Relationship(id='a1400ac0396640518b2941e48c694299', short_id='75', source='SINGAPORE', target='PRESIDENT', weight=16.0, description="The President of Singapore plays a crucial role in the governance of the nation, representing Singapore both domestically and internationally. The President is viewed as a non-partisan head of state, responsible for safeguarding the treasures of good administration in Singapore. The current campaign is focused on electing the country's ninth President, with Singaporeans emphasizing the need for an independent leader who supports the nation and its people. Discussions surrounding the President's role in Singaporean politics and the responsibility towards the citizens are prominent, highlighting the significance of this position in the country's political landscape.", description_embedding=None, text_unit_ids=['08447d67cfdc25ac866c19c2cc8682e7', '2581675b5cfb5e652925b09690fa87f5', '28308ffe53cfc261bde46b37700914fe', '333b5ed3f8ce23623acd52c4385d196a', '3fac5e88de7a91b89cb8a4a5442e41b1', '4801dec377d97e15f0a187c3f80cd8ee', '4d6963215bd99c520483f2df08eae14e', '4f5f4aef7d1fe5e5d32047f414c1a621', '6abb5bf886176cdb305acdd3671353f3', '7a135689160d781a60b2b66f63b1f846', '9843aa30abc2bc85616266a852ac0b78', 'cf718da77378d17a615be2ec62a43eee', 'd2b4f4c5737d51e4b18b410f929f4e95', 'd655e974556801be7eb2f9a63230a6bc', 'dd5fe501b09dfa91e99e51ecd0f53fbb', 'df4744e84e776a58db744d62377217f6'], document_ids=None, attributes={'rank': 880}),
#  Relationship(id='61f097a6225041dbb22abf8c2abcde6e', short_id='76', source='SINGAPORE', target='CLIMATE CHANGE', weight=4.0, description='SINGAPORE, a country that has experienced warming due to climate change, faces a long-term threat to its existence as climate change may disrupt its food supply in the long run. Despite these challenges, Singapore has taken proactive measures by setting clear targets to address climate change.', description_embedding=None, text_unit_ids=['9843aa30abc2bc85616266a852ac0b78', 'bdc8095dec8be8559538661d621cafb3', 'd231fa3fe0667bd87f39d4567da29f45', 'da3ff5880a9db704d9d80d0ae1115e48'], document_ids=None, attributes={'rank': 630}),
#  Relationship(id='ca1201b6ffea4f90a6debf4ae2b854bd', short_id='77', source='SINGAPORE', target='NATIONAL INTERESTS', weight=2.0, description="Both Singapore and its national interests are closely intertwined, with a focus on advancing long-term goals. The entity has been consistently representing Singapore's flag and interests, demonstrating a strong commitment to serving the country's objectives. The individual's actions align with the overarching goal of promoting and safeguarding Singapore's national interests on a continuous basis.", description_embedding=None, text_unit_ids=['40752b26a871a3092e319e716249a428', '6948bffd9c37b46d42ca7ab3388c39e7'], document_ids=None, attributes={'rank': 615}),
#  Relationship(id='da32481040114744afb8fd7805f11831', short_id='78', source='SINGAPORE', target='VOICE OF REASON', weight=1.0, description='Singapore aims to remain a voice of reason', description_embedding=None, text_unit_ids=['40752b26a871a3092e319e716249a428'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='2dc955fee9094dbf8476920a145754a8', short_id='79', source='SINGAPORE', target='SOLUTIONS', weight=1.0, description='Singapore strives for solutions that are of mutual benefit', description_embedding=None, text_unit_ids=['40752b26a871a3092e319e716249a428'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='e19ccd2c892243d6b05a2c9d0568a2c8', short_id='80', source='SINGAPORE', target='PARTNER', weight=1.0, description='Singapore aims to be a partner that others find worthwhile to engage with', description_embedding=None, text_unit_ids=['40752b26a871a3092e319e716249a428'], document_ids=None, attributes={'rank': 615}),
#  Relationship(id='cea92a83fcb7497ea54c9c790310f679', short_id='81', source='SINGAPORE', target='FAMILY', weight=2.0, description='SINGAPORE is a place where the concept of FAMILY is evolving. The individual mentioned in the data has a family in Singapore, indicating a personal connection to the changing dynamics of family structures in the country.', description_embedding=None, text_unit_ids=['38c293a622a401ed2929f60b2e1f109b', 'f85283aa533f80cb7c558926afa26701'], document_ids=None, attributes={'rank': 661}),
#  Relationship(id='42c66332b4e94ecbb4bea7a206a7ab4b', short_id='82', source='SINGAPORE', target='NG KOK SONG', weight=7.0, description='Ng Kok Song, a prominent figure in Singapore, has a strong connection to the country as he grew up there. He is currently a presidential candidate and is actively involved in discussing the political situation in Singapore. Ng Kok Song is vying to represent Singapore as the head of state, showcasing his dedication to serving the community. He came in second in a previous presidential election, demonstrating his experience and support within the political landscape of Singapore.', description_embedding=None, text_unit_ids=['3133f9a767995463394b1f2958188e3d', '3a4433439cfe8cfa27ee3bbdbffce3a7', '6dea7ce066e526c0378bd7017b0481d1', '89452d4e8745140b84f4532ae2c5484c', 'a2f69dded31c5fe6dc1239ca5d44b7dc', 'a6d521fac90e5c8042cf60e89b40d67d', 'cb94ef7a0064821bd296d9272276ed8a'], document_ids=None, attributes={'rank': 758}),
#  Relationship(id='a304028f4297493182b1d76104868ee7', short_id='83', source='SINGAPORE', target='FIRST LADY', weight=1.0, description='The concept of the First Lady is discussed in relation to Singapore', description_embedding=None, text_unit_ids=['6dea7ce066e526c0378bd7017b0481d1'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='205e6fc44d1f458c9a923ed043f77f87', short_id='84', source='SINGAPORE', target='MS LAU', weight=2.0, description='Ms Lau, after residing in Singapore for 18 years, made the decision to become a Singapore citizen and live in the country for the rest of her life.', description_embedding=None, text_unit_ids=['0508bd62bff07802ff608582a41039d2', '2acc2212980f0ae0c093abed3d0a908a'], document_ids=None, attributes={'rank': 628}),
#  Relationship(id='f2e2adf803ab437eb0d9eaea85cb3691', short_id='85', source='SINGAPORE', target='JANE YUMIKO ITTOGI', weight=3.0, description='SINGAPORE is a country where JANE YUMIKO ITTOGI has lived since she was three years old. Originally born in Japan, JANE YUMIKO ITTOGI later became a Singaporean citizen.', description_embedding=None, text_unit_ids=['055dc6644b41535f455dd8e7214d1a7a', '2acc2212980f0ae0c093abed3d0a908a', '2d657a23d34c9c4604dbfbb334159394'], document_ids=None, attributes={'rank': 626}),
#  Relationship(id='839f5805f0844d78b6128b7cc89e7b26', short_id='86', source='SINGAPORE', target='SINGAPOREANS', weight=4.0, description='"SINGAPORE is the home country of SINGAPOREANS, who are the citizens of SINGAPORE. SINGAPOREANS should have the sole decision-making power in SINGAPOREAN politics. The victims were SINGAPOREANS who were travelling from SINGAPORE."', description_embedding=None, text_unit_ids=['2acc2212980f0ae0c093abed3d0a908a', '68f7d760e7b6814a76cdee20a3606411', '6d514e32e0a7e64ddc9af2095add0402', '72ae83da9f3577763bc5c83effc669ee'], document_ids=None, attributes={'rank': 787}),
#  Relationship(id='ad7356fcc49d46b8b0bcbd3facc6eb27', short_id='87', source='SINGAPORE', target='POLITICAL LEADERS', weight=1.0, description='Some political leaders in Singapore were not born in Singapore', description_embedding=None, text_unit_ids=['2acc2212980f0ae0c093abed3d0a908a'], document_ids=None, attributes={'rank': 622}),
#  Relationship(id='24fe71a8cc5c4e3d9d118e62bd89b7ce', short_id='88', source='SINGAPORE', target='LEADERS', weight=1.0, description='The text discusses the history and contributions of leaders in Singapore', description_embedding=None, text_unit_ids=['3c4014c9476866608345f99f33567152'], document_ids=None, attributes={'rank': 616}),
#  Relationship(id='a0ec51057c714be3bac6986738043969', short_id='89', source='SINGAPORE', target='CITIZENS', weight=1.0, description='Citizenship criteria are being discussed in the context of Singapore', description_embedding=None, text_unit_ids=['5f7d274f9929005453cf6cb69d68db48'], document_ids=None, attributes={'rank': 626}),
#  Relationship(id='4b25c6b2a0694e48808b30781c5a3677', short_id='90', source='SINGAPORE', target='SIRIBUN', weight=1.0, description='Siribun is a food importer located in Singapore', description_embedding=None, text_unit_ids=['6e5e14d1909c8191e8fcc2a35aad994c'], document_ids=None, attributes={'rank': 614}),
#  Relationship(id='d7deefda3ddb4c70bf0045ba62bd9d3b', short_id='91', source='SINGAPORE', target='FOOD', weight=2.0, description="SINGAPORE is taking measures to ensure food security by enforcing requirements for imported FOOD to meet the country's standards.", description_embedding=None, text_unit_ids=['2ec826305c7dc2bc4cb1540d38a3fa24', 'a3ad4bd5903b03756706368386e2b778'], document_ids=None, attributes={'rank': 627}),
#  Relationship(id='155e65f6e9ff4b4b84d369ab1e4dfe26', short_id='92', source='SINGAPORE', target='MEAT AND MEAT PRODUCTS', weight=1.0, description='Meat and meat products can only be imported from approved sources in compliant countries', description_embedding=None, text_unit_ids=['a3ad4bd5903b03756706368386e2b778'], document_ids=None, attributes={'rank': 612}),
#  Relationship(id='2381eaef835e4513aa31ae5d5c4c4996', short_id='93', source='SINGAPORE', target='SEAFOOD PRODUCTS', weight=1.0, description="Seafood products must meet Singapore's food safety requirements", description_embedding=None, text_unit_ids=['a3ad4bd5903b03756706368386e2b778'], document_ids=None, attributes={'rank': 613}),
#  Relationship(id='bb82a85be6a349729b9246faabab87c0', short_id='94', source='SINGAPORE', target='RESERVES', weight=5.0, description='SINGAPORE, a country known for its financial stability, holds RESERVES to support its economy in times of need. These reserves are crucial for financial defence, as evidenced by decisions made to draw down on them during the COVID-19 pandemic. The reserves are guarded by two keys, one held by the government and the other by the president, highlighting the importance placed on their protection and management.', description_embedding=None, text_unit_ids=['1d64398381a69c28f05366c94d1a8e15', '2a76cde17fc6dd135067974e2cc8986e', '46d20e4165e9db8716c8667fb5dce1d0', 'b1662fe2d7fc8327b091ebc740b53057', 'cfe6e25048b3b4359bf579b654e4f50c'], document_ids=None, attributes={'rank': 720}),
#  Relationship(id='c904aeedd58b4da98038fa23dc870809', short_id='95', source='SINGAPORE', target='ECONOMIC GROWTH', weight=1.0, description='Singapore experienced fast economic growth in the 1970s and 1980s', description_embedding=None, text_unit_ids=['61fdb498e7646804caaa7229c990ec50'], document_ids=None, attributes={'rank': 617}),
#  Relationship(id='d508f6e12cb7497594362ca646107bc3', short_id='96', source='SINGAPORE', target='POLICE', weight=4.0, description='SINGAPORE, in particular the Singapore Police Force, is actively involved in various law enforcement activities within the country. They are currently investigating phishing scams, suspected involvement in scams, and cases of child abuse. The police have made arrests in connection to these incidents and are working to ensure the safety and security of the community.', description_embedding=None, text_unit_ids=['815855bbcd589c7ad71413fdb994c975', 'b5fad0d5f524052e21096d59d5c5830f', 'e1328ac675f821d7aa727bfd39c0ebe7', 'ec49431295dc5342ce9d8c0f442c96f1'], document_ids=None, attributes={'rank': 799}),
#  Relationship(id='af49413964d24161afe5aa0d490d7ce8', short_id='97', source='SINGAPORE', target='ALFA ROMEO', weight=1.0, description='Alfa Romeo introduces its first hybrid model in Singapore', description_embedding=None, text_unit_ids=['55dd22e01b3589dd5116c2172b2c2be8'], document_ids=None, attributes={'rank': 612}),
#  Relationship(id='2126c393ff004be4b9bb6d5490dc7cb8', short_id='98', source='SINGAPORE', target='HALIMAH YACOB', weight=2.0, description='SINGAPORE is a country in Southeast Asia. HALIMAH YACOB is the outgoing President of SINGAPORE, having served in that role.', description_embedding=None, text_unit_ids=['34bd27e92edb947b8f5a19ebb792985a', 'cdf1d9c993dee233902996d2e817c7f6'], document_ids=None, attributes={'rank': 630}),
#  Relationship(id='e4fc3733fdfb4cb386c5381344e23663', short_id='99', source='SINGAPORE', target='THARMAN SHANMUGARATNAM', weight=9.0, description='Tharman Shanmugaratnam, a prominent figure in Singapore, has a strong political background, having served as a senior minister, Jurong GRC MP, and elected as the ninth President of Singapore. Despite being involved in activism, he is now set to become the next President of Singapore, having won the presidential election.', description_embedding=None, text_unit_ids=['0575372381c88ed32619f6df62c8c29c', '14b6f562a4fdb87844957d6b418c67d2', '34bd27e92edb947b8f5a19ebb792985a', '4832dc0a65ed59a3411d8e32b66c0f8f', '6ae728e75dbc070f36c542a36b8c137b', 'a6d521fac90e5c8042cf60e89b40d67d', 'd17345590aee8c8551e90a578ee06c54', 'dd7c92029b3dfd739d5b37c287e10fa0', 'f985aa03d059b5a8415088b5f8171694'], document_ids=None, attributes={'rank': 728}),
#  Relationship(id='6f0fda62210d4c218230362699b80c20', short_id='100', source='SINGAPORE', target='COVID', weight=1.0, description='Singapore emerged stronger and more resilient after the COVID pandemic', description_embedding=None, text_unit_ids=['5ec9b5560d1018ff92ee54360272d015'], document_ids=None, attributes={'rank': 617}),
#  Relationship(id='83d457b457b1448e93fd0cefc38a6f74', short_id='101', source='SINGAPORE', target='CEDRIC GROLET', weight=3.0, description='Cedric Grolet, a renowned pastry chef, recently opened his first patisserie in Singapore, marking his debut in Asia. This new outlet in Singapore signifies a significant milestone in his culinary career, showcasing his exquisite pastries to the local community.', description_embedding=None, text_unit_ids=['07ab6d0a0836e9d1d61bd9a0cb4b337c', '1606a6d70eabf94c451527f6e67c341a', 'a456e52f218ed6a963d246137cf24c6e'], document_ids=None, attributes={'rank': 626}),
#  Relationship(id='7927a3f5e2b24efab07ef341053a708e', short_id='102', source='SINGAPORE', target='DIVERSITY OF VIEWS', weight=1.0, description="Singapore's challenge is to manage diversity of views to prevent division", description_embedding=None, text_unit_ids=['d73b645ef22b6fd91d8f2f357ef58dcf'], document_ids=None, attributes={'rank': 613}),
# ...
#  Relationship(id='706b012eb75d42f894b58b180aba012a', short_id='961', source='PUBLIC', target='MALAYSIA', weight=1.0, description='The public in Malaysia started to wonder about the governance and corruption issues', description_embedding=None, text_unit_ids=['b34bf3dfbb52311ac8ddd28b06685ed9'], document_ids=None, attributes={'rank': 156}),
#  Relationship(id='b6a618e058484d3291003a0cd2727330', short_id='962', source='PUBLIC', target='BANK ACCOUNT', weight=1.0, description='The public is advised to reject requests to use their bank accounts to prevent being held accountable for crimes', description_embedding=None, text_unit_ids=['e674b0717720e9f7ba118112e87fe96b'], document_ids=None, attributes={'rank': 100}),
#  Relationship(id='87dfc4759b5c4e2188113eb5adecebf5', short_id='963', source='PUBLIC', target='CELLPHONE LINES', weight=1.0, description='The public is advised to reject requests to use their cellphone lines to prevent being held accountable for crimes', description_embedding=None, text_unit_ids=['e674b0717720e9f7ba118112e87fe96b'], document_ids=None, attributes={'rank': 99}),
#  Relationship(id='e8a52d5f4dfa4ff3a04a471f74864d1f', short_id='964', source='PUBLIC', target='VOTING', weight=1.0, description='The public can vote for their favorite works online', description_embedding=None, text_unit_ids=['e4060ce7d375978b8d494d2d064392f9'], document_ids=None, attributes={'rank': 105}),
#  Relationship(id='bd3122a7f88d412f96b99b163b094cad', short_id='965', source='PUBLIC', target='INTERNATIONAL COUNCILS', weight=1.0, description='Leadership of international councils involves representing the public and advancing national interests', description_embedding=None, text_unit_ids=['abe46fcfc5e26f0cb73efeabf9a5bc6a'], document_ids=None, attributes={'rank': 100}),
#  Relationship(id='ea7da057d4414e3a92effe2e9fba7bab', short_id='966', source='PUBLIC', target='STRATEGIES', weight=1.0, description='The public is consulted actively for rethinking strategies for the future', description_embedding=None, text_unit_ids=['abe46fcfc5e26f0cb73efeabf9a5bc6a'], document_ids=None, attributes={'rank': 100}),
#  Relationship(id='43df782f5439409bb9ad5a27b9ad9089', short_id='967', source='PUBLIC', target='GLOBAL CRISES', weight=1.0, description='New global crises require collaboration with the public and government', description_embedding=None, text_unit_ids=['abe46fcfc5e26f0cb73efeabf9a5bc6a'], document_ids=None, attributes={'rank': 99}),
#  Relationship(id='ec49fa99cb53443bbd82e484ac4b1826', short_id='968', source='PUBLIC', target='DOMESTIC ENVIRONMENT', weight=1.0, description='Changes in the domestic environment impact the relationship between the public and government', description_embedding=None, text_unit_ids=['abe46fcfc5e26f0cb73efeabf9a5bc6a'], document_ids=None, attributes={'rank': 99}),
#  Relationship(id='af3673efdd8b41d7a7fbeed5743b952b', short_id='969', source='PUBLIC', target='CRIMES', weight=1.0, description='Members of the public should avoid being involved in criminal activities', description_embedding=None, text_unit_ids=['f9b3cad67419ffe8f3dfc8c709784553'], document_ids=None, attributes={'rank': 101}),
#  Relationship(id='ebc96663eea8408c8fe9f4ece3f2d9e1', short_id='970', source='ISWARANS', target='MP ALLOWANCE', weight=1.0, description='Mr. Iswaran is mentioned in relation to his MP allowance', description_embedding=None, text_unit_ids=['e955cfcbb3147ecd4ffa8e321edf0166'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='6f254dd03a1446aaac60860f971ef7d5', short_id='971', source='MP ALLOWANCE', target='MINISTER-IN-CHARGE OF THE PUBLIC SERVICE', weight=1.0, description='Minister Chan Chun Sing clarifies the process of withholding MPs allowance', description_embedding=None, text_unit_ids=['e955cfcbb3147ecd4ffa8e321edf0166'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='3bac4a6b14c249e8883716deb1b1146b', short_id='972', source='MINISTER-IN-CHARGE OF THE PUBLIC SERVICE', target='MP', weight=1.0, description='The Minister-in-charge of the Public Service clarifies matters related to MPs', description_embedding=None, text_unit_ids=['a741151b42fd7469135a2e878306a4f7'], document_ids=None, attributes={'rank': 31}),
#  Relationship(id='fe55dbc2819b483a8da5bdaffaaab030', short_id='973', source='MINISTER-IN-CHARGE OF THE PUBLIC SERVICE', target='MS CHAN LAI FUNG', weight=1.0, description='Minister-in-charge of the Public Service expressed gratitude to Ms Chan Lai Fung for her leadership', description_embedding=None, text_unit_ids=['bcd091d2cdae25bd1bdfaca5c56d2161'], document_ids=None, attributes={'rank': 11}),
#  Relationship(id='4a49e9f8f7c34d91ad316fe44db09b14', short_id='974', source='MINISTER-IN-CHARGE OF THE PUBLIC SERVICE', target='MR LOH KHUM YEAN', weight=1.0, description='Minister-in-charge of the Public Service expressed gratitude to Mr Loh Khum Yean for his leadership', description_embedding=None, text_unit_ids=['bcd091d2cdae25bd1bdfaca5c56d2161'], document_ids=None, attributes={'rank': 7}),
#  Relationship(id='51c7a24bb27642d8b7634e6c55a72164', short_id='975', source='MP', target='PARLIAMENT', weight=1.0, description='MPs serve in parliament', description_embedding=None, text_unit_ids=['a741151b42fd7469135a2e878306a4f7'], document_ids=None, attributes={'rank': 93}),
#  Relationship(id='0025a12bebe3493dbe2675440e4402ae', short_id='976', source='MP', target='SUSPENSION', weight=2.0, description='MPs may be suspended from parliamentMPs may be suspended from their duties', description_embedding=None, text_unit_ids=['a741151b42fd7469135a2e878306a4f7'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='7fe44d222e0949ad8bc99c0b5de8867c', short_id='977', source='MP', target='ALLOWANCE', weight=1.0, description='MPs receive allowances for their service', description_embedding=None, text_unit_ids=['a741151b42fd7469135a2e878306a4f7'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='c3a1d47c716a415f8c9a03c0d421166f', short_id='978', source='MP', target='PARLIAMENT (PRIVILEGES, IMMUNITIES AND POWERS) ACT', weight=1.0, description='MPs are governed by the Parliament Act', description_embedding=None, text_unit_ids=['a741151b42fd7469135a2e878306a4f7'], document_ids=None, attributes={'rank': 28}),
#  Relationship(id='20ef330b6af84903aa368c7b87a45f51', short_id='979', source='MP', target='MS RAEESAH KHAN', weight=1.0, description='Ms. Raeesah Khan resigned as an MP', description_embedding=None, text_unit_ids=['b10363cac8d9b2e2781ed49542047322'], document_ids=None, attributes={'rank': 31}),
#  Relationship(id='66906c1479194e7faeb859f267b2512a', short_id='980', source='MP', target='TRADE AND INDUSTRY MINISTER', weight=1.0, description='The Trade and Industry Minister is also an MP for Chua Chu Kang GRC', description_embedding=None, text_unit_ids=['2dd79bf57c9438271a719873d6fd2c42'], document_ids=None, attributes={'rank': 31}),
#  Relationship(id='126645adf74449d1af2641ebe092e9d4', short_id='981', source='MP', target='THARMAN SHANMUGARATNAM', weight=1.0, description='Tharman Shanmugaratnam was first elected as a Member of Parliament in 2001', description_embedding=None, text_unit_ids=['158115d1ed97d339ae78a0c1ea22d772'], document_ids=None, attributes={'rank': 144}),
#  Relationship(id='8d081d9f5f804eebb936ce36ffa79609', short_id='982', source='MP', target='MR. THARMAN', weight=1.0, description='Tharman is retiring as an MP in Jurong', description_embedding=None, text_unit_ids=['4670f7fe8232ec2d16ec43819ecf1155'], document_ids=None, attributes={'rank': 60}),
#  Relationship(id='1e0deabf36c94c5fa804d4a4c671ad21', short_id='983', source='MP', target='JURONG', weight=2.0, description='JURONG is the constituency where the MP served and is now retiring from representing as a Member of Parliament.', description_embedding=None, text_unit_ids=['4670f7fe8232ec2d16ec43819ecf1155', 'f2f916b32284b44ee927e4b58451b58b'], document_ids=None, attributes={'rank': 35}),
#  Relationship(id='4fbf72f6748347aa8e46ffb273378d4f', short_id='984', source='MP', target='ELECTORAL TERM', weight=1.0, description='MPs serve their constituents during the current electoral term', description_embedding=None, text_unit_ids=['4670f7fe8232ec2d16ec43819ecf1155'], document_ids=None, attributes={'rank': 28}),
#  Relationship(id='540b3d9061d449f6b6d3206a56b632b4', short_id='985', source='MP', target='FELLOW MPS', weight=1.0, description='The MP expresses confidence in fellow MPs to serve residents in Jurong', description_embedding=None, text_unit_ids=['f2f916b32284b44ee927e4b58451b58b'], document_ids=None, attributes={'rank': 28}),
#  Relationship(id='a182b13b44884cadbe6fae01611c7400', short_id='986', source='MP', target='TAMAN JURONG WARD', weight=1.0, description='Tharman was an MP in Taman Jurong ward', description_embedding=None, text_unit_ids=['711e792eeafbbf23474c0010d50192e6'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='ebe08ff703954f15b04e39201be32635', short_id='987', source='MP', target='PAP', weight=1.0, description='PAP has a structure to replace MPs in unforeseen circumstances', description_embedding=None, text_unit_ids=['be35ff4d2f94ca376c6b581f96997724'], document_ids=None, attributes={'rank': 84}),
#  Relationship(id='4ac2a2028a404fe7b36023bf004f126d', short_id='988', source='MP', target='POLITICAL REPRESENTATION', weight=1.0, description='MPs play a crucial role in political representation', description_embedding=None, text_unit_ids=['b325bec89fccb8acea26c6cee78467f0'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='33126c82b37246eb9d1f61bd6f0ddea4', short_id='989', source='MP', target='CONSTITUENCIES', weight=1.0, description='MPs represent specific constituencies', description_embedding=None, text_unit_ids=['b325bec89fccb8acea26c6cee78467f0'], document_ids=None, attributes={'rank': 28}),
#  Relationship(id='e8b09d767f3b43cb80460602baf91406', short_id='990', source='MP', target='RESIGNATIONS', weight=1.0, description='MP resignations are a common occurrence in Parliament', description_embedding=None, text_unit_ids=['b325bec89fccb8acea26c6cee78467f0'], document_ids=None, attributes={'rank': 31}),
#  Relationship(id='b68896bf520e4c39902aab2df27b068b', short_id='991', source='MP', target='SPEAKER', weight=3.0, description='The Speaker, a prominent figure in the political realm, has a formal relationship with MPs. In a recent discussion, the Speaker delved into the dynamics of the relationship between the Speaker and an MP. Additionally, the Speaker is frequently mentioned in relation to MPs, indicating a significant role in the interactions within the political sphere.', description_embedding=None, text_unit_ids=['30c9e3130ad11c3ba588e758bc1ec662', 'a5516679c97dcc3ce28c5917e88324d2', 'fc6a5df8dae717929c14d2b1cf180d32'], document_ids=None, attributes={'rank': 52}),
#  Relationship(id='288debc0a7f54cafa43fcd1a81bf6931', short_id='992', source='MP', target='RESIGNATION', weight=1.0, description='Resignation may involve MPs stepping down from their positions', description_embedding=None, text_unit_ids=['fc6a5df8dae717929c14d2b1cf180d32'], document_ids=None, attributes={'rank': 35}),
#  Relationship(id='103c88f30d324911ada510e48485a2ef', short_id='993', source='MP', target='ALJUNIED GRC', weight=1.0, description='The MP represents Aljunied GRC', description_embedding=None, text_unit_ids=['bd8f0b9bb7b9cd125592c525b021730e'], document_ids=None, attributes={'rank': 37}),
#  Relationship(id='0991b1ab73b04d999004b1743489912e', short_id='994', source='MP', target='TAMAN JURONG', weight=2.0, description="The MP, who is mentioned as retiring, has built deep-rooted relationships with residents and volunteers in Taman Jurong. This indicates a strong connection and engagement with the community in Taman Jurong throughout the MP's tenure.", description_embedding=None, text_unit_ids=['15ea0bfe5e1044bb6218279d453157d6', '879957d8c190435d56edfb8d12e04515'], document_ids=None, attributes={'rank': 36}),
#  Relationship(id='97b6925fcf4042d8a9769a5a0def6425', short_id='995', source='MP', target='JURONG GRC', weight=2.0, description='The MP represents Jurong GRC as an electoral constituency and is part of a group of fellow MPs in Jurong GRC who work hard to serve residents. The MP plays a significant role in representing the interests of the community within Jurong GRC.', description_embedding=None, text_unit_ids=['15ea0bfe5e1044bb6218279d453157d6', '879957d8c190435d56edfb8d12e04515'], document_ids=None, attributes={'rank': 40}),
#  Relationship(id='a5b34163b13746da8f3f05d4c6c41c6a', short_id='996', source='MP', target='COLLEAGUES', weight=1.0, description='The MP acknowledges the teamwork and contributions of colleagues in Government', description_embedding=None, text_unit_ids=['879957d8c190435d56edfb8d12e04515'], document_ids=None, attributes={'rank': 33}),
#  Relationship(id='64443959b41b4d5591cedc0f4005bed2', short_id='997', source='PARLIAMENT', target='PRESIDENT', weight=20.0, description='In Singapore, the relationship between the "PARLIAMENT" and the "PRESIDENT" is crucial in the government\'s decision-making process. "PARLIAMENT" holds significant power, as it can overrule the "PRESIDENT" in certain circumstances, such as through a two-thirds majority vote. While "PARLIAMENT" is responsible for appointing the "PRESIDENT" and setting fiscal policies, the "PRESIDENT" plays a key role in interacting with "PARLIAMENT" on various matters. Despite this, the "PRESIDENT" does not take instructions from "PARLIAMENT," indicating a balance of power between the two entities. The "PRESIDENT\'s" veto on spending reserves can be overridden by "PARLIAMENT," highlighting the checks and balances within Singapore\'s political system. Overall, the "PARLIAMENT," "PRESIDENT," and "Cabinet" are integral components of Singapore\'s government and political landscape.', description_embedding=None, text_unit_ids=['00dddedd482f4d0cfcc5ef76337f0ef6', '0a6f58a07ada3b6ffc6d2c8760b4020d', '2581675b5cfb5e652925b09690fa87f5', '3f0df53682d9fa26568835aa9d162c4d', '4f5f4aef7d1fe5e5d32047f414c1a621', '586b430ea3fd15c4918d081b7209a433', '618011d08f28d204be0b5c571fc570d3', '6afc9cb3a15624feba5c7fcf07bb5050', '89b310b6d7fc9cf0933430eaa9e1695a', '8c0f7792bdb61f96fac29ccb0a8120cb', '8e57bb429b535622481aa84da1dc0d3d', 'aa7a3b812c8a8a24da38035583e6f5a5', 'b375481c7b8cce966d8540c30c6e4afe', 'b44a296242182d5649e588cffeafbe4a', 'b5e9de8b9474631c984ce6d2c6ac5b3e', 'c9cd9fe3b70e900835b53cace0a2dd3c', 'cfe6e25048b3b4359bf579b654e4f50c', 'e43a729e72fb751ebdf5f9862fbdc5bc', 'e77f564c914b7b0528ae2cfb923874a9'], document_ids=None, attributes={'rank': 335}),
#  Relationship(id='11563f1feed24708b22390cde562b70e', short_id='998', source='PARLIAMENT', target='OPPOSITION', weight=1.0, description='The opposition members are mentioned in the context of their interactions in Parliament', description_embedding=None, text_unit_ids=['018c3f59d6d84eb63da51d40afa5e66f'], document_ids=None, attributes={'rank': 86}),
#  Relationship(id='f4edee651b4f41bb8cd0ac00b539ca36', short_id='999', source='PARLIAMENT', target='GOVERNMENT', weight=4.0, description='PARLIAMENT and GOVERNMENT are closely intertwined as the Government openly debated and made statements in Parliament. The matter involving the Government was openly debated in Parliament, leading to the passing of measures to combat cyber scams. This highlights the active role of both entities in addressing important issues within the legislative framework.', description_embedding=None, text_unit_ids=['251ac27599fe5832823dab37861d339f', '89ab227e0436f786980c9f6f18dcccf7', 'e22fd81510e8cc8360a03cba5f83822f', 'f112c9477c2ccabc9bc0ee31ca59607d'], document_ids=None, attributes={'rank': 234}),
#  ...]

# %%
# %pip install yfiles_jupyter_graphs --quiet
from yfiles_jupyter_graphs import GraphWidget


# converts the entities dataframe to a list of dicts for yfiles-jupyter-graphs
def convert_entities_to_dicts(df):
    """Convert the entities dataframe to a list of dicts for yfiles-jupyter-graphs."""
    nodes_dict = {}
    for _, row in df.iterrows():
        # Create a dictionary for each row and collect unique nodes
        node_id = row["title"]
        if node_id not in nodes_dict:
            nodes_dict[node_id] = {
                "id": node_id,
                "properties": row.to_dict(),
            }
    return list(nodes_dict.values())


# converts the relationships dataframe to a list of dicts for yfiles-jupyter-graphs
def convert_relationships_to_dicts(df):
    """Convert the relationships dataframe to a list of dicts for yfiles-jupyter-graphs."""
    relationships = []
    for _, row in df.iterrows():
        # Create a dictionary for each row
        relationships.append({
            "start": row["source"],
            "end": row["target"],
            "properties": row.to_dict(),
        })
    return relationships


w = GraphWidget()
w.directed = True
w.nodes = convert_entities_to_dicts(entity_df)
w.edges = convert_relationships_to_dicts(relationship_df)

# %%
# show title on the node
w.node_label_mapping = "title"


# map community to a color
def community_to_color(community):
    """Map a community to a color."""
    colors = [
        "crimson",
        "darkorange",
        "indigo",
        "cornflowerblue",
        "cyan",
        "teal",
        "green",
    ]
    return (
        colors[int(community) % len(colors)] if community is not None else "lightgray"
    )


def edge_to_source_community(edge):
    """Get the community of the source node of an edge."""
    source_node = next(
        (entry for entry in w.nodes if entry["properties"]["title"] == edge["start"]),
        None,
    )
    source_node_community = source_node["properties"]["community"]
    return source_node_community if source_node_community is not None else None


w.node_color_mapping = lambda node: community_to_color(node["properties"]["community"])
w.edge_color_mapping = lambda edge: community_to_color(edge_to_source_community(edge))
# map size data to a reasonable factor
w.node_scale_factor_mapping = lambda node: 0.5 + node["properties"]["size"] * 1.5 / 20
# use weight for edge thickness
w.edge_thickness_factor_mapping = "weight"

# %%
# # Use the circular layout for this visualization. For larger graphs, the default organic layout is often preferrable.
w.circular_layout()

# %%
# display(w)

# %% [markdown]
# ###
# Visualizing the result context of `graphrag` queries

# %%
# setup (see also ../../local_search.ipynb)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)

description_embedding_store = LanceDBVectorStore(
    collection_name="entity_description_embeddings",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)
entity_description_embeddings = store_entity_semantic_embeddings(
    entities=entities, vectorstore=description_embedding_store
)
# covariate_df = pd.read_parquet(f"{INPUT_DIR}/{COVARIATE_TABLE}.parquet")
# claims = read_indexer_covariates(covariate_df)
# covariates = {"claims": claims}
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

api_key = "sk-proj-mTeFxdXu5jqzt27AzGbwT3BlbkFJKaWpXqAhdo7lbF9BQsFy"
llm_model = "gpt-3.5-turbo"
embedding_model = "text-embedding-3-small"

llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_type=OpenaiApiType.OpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

text_embedder = OpenAIEmbedding(
    api_key=api_key,
    api_base=None,
    api_type=OpenaiApiType.OpenAI,
    model=embedding_model,
    deployment_name=embedding_model,
    max_retries=20,
)

context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    # covariates=covariates,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,  # if the vectorstore uses entity title as ids, set this to EntityVectorStoreKey.TITLE
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

local_context_params = {
    "text_unit_prop": 0.5,
    "community_prop": 0.1,
    "conversation_history_max_turns": 5,
    "conversation_history_user_turns_only": True,
    "top_k_mapped_entities": 10,
    "top_k_relationships": 10,
    "include_entity_rank": True,
    "include_relationship_weight": True,
    "include_community_rank": False,
    "return_candidate_context": False,
    "embedding_vectorstore_key": EntityVectorStoreKey.ID,  # set this to EntityVectorStoreKey.TITLE if the vectorstore uses entity title as ids
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
}

llm_params = {
    "max_tokens": 2_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000=1500)
    "temperature": 0.0,
}

search_engine = LocalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)
# Out:
# /home/tjustin/Projects/Graph-RAG-MS /graphrag/query/indexer_adapters.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entity_df["community"] = entity_df["community"].fillna(-1)
# /home/tjustin/Projects/Graph-RAG-MS /graphrag/query/indexer_adapters.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entity_df["community"] = entity_df["community"].astype(int)

# %% [markdown]
# ## Run local search on sample queries

# %%
result = await search_engine.asearch("Who are the candidates for the 2023 presidential elections")
print(result.response)
# Out:
# In the upcoming 2023 Presidential Election in Singapore, several notable candidates are vying for the position of President. Among them are Mr. Ng Kok Song, a former chief investment officer of the sovereign wealth fund GIC, Mr. Tharman Shanmugaratnam, a former senior minister, and Mr. Tan Kin Lian, the former chief executive officer of NTUC Income insurance cooperative [Data: Sources (763); Relationships (1637, 6161, 4858)]. These candidates bring diverse backgrounds and experiences to the electoral landscape, each emphasizing their contributions to Singapore and their approach to exercising custodial powers if elected as President [Data: Sources (763); Relationships (509, 2781, 6213, 6206, 1886, +more)].
#
# The candidates are actively engaging with voters through various platforms, including social media, interviews, and campaign events, to present their visions for the country and connect with the electorate [Data: Sources (763); Relationships (3613, 6256, 6258, 6265, +more)]. Their ability to address key issues, demonstrate leadership qualities, and differentiate themselves in the electoral arena will play a crucial role in influencing the election outcome and shaping the future direction of Singapore [Data: Sources (763); Relationships (509, 2781, 6213, 6206, 1886, +more)].
#
# Moreover, the candidates are focusing on their contributions to Singapore and their commitment to exercising custodial powers responsibly if elected as President. This emphasis underscores the importance of leadership qualities, integrity, and dedication to serving the country's interests [Data: Sources (763); Entities (394, 1053, 88, 2557, +more)]. Political parties play a significant role in endorsing candidates for the presidential race, influencing voter perceptions, and shaping the overall electoral landscape [Data: Sources (763); Relationships (10947, 6201, 6274, 2382, +more)].
#
# As the election process unfolds, the candidates' engagement with voters, communication strategies, and alignment with the regulatory framework governing campaign activities will be critical factors in determining their electoral success and the future leadership of Singapore [Data: Sources (763); Relationships (5994, 1667, 16653, 14395, +more)]. The upcoming election presents a significant opportunity for Singaporeans to participate in the democratic process and elect a candidate who reflects their values and aspirations for the country's future.

# %% [markdown]
# ## Inspecting the context data used to generate the response

# %%
result.context_data["entities"].head()
# Out:
#       id                      entity  \
# 0   4522   THREE ASPIRING CANDIDATES
# 1    328  PRESIDENTIAL ELECTION 2023
# 2  10614  2023 PRESIDENTIAL ELECTION
# 3   7389                 NOMINATIONS
# 4  13654      PRESIDENTIAL ASPIRANTS
#
#                                          description number of relationships  \
# 0  The three aspiring candidates are individuals ...                       2
# 1  Presidential Election 2023 is a specific elect...                       2
# 2  The 2023 Presidential Election is a significan...                       6
# 3  Nominations have been made for the presidentia...                       1
# 4  Presidential aspirants are individuals running...                       2
#
#    in_context
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
result.context_data["relationships"].head()
# print(len(result.context_data["relationships"]))
# Out:
#      id       source                            target  \
# 0  2346          ELD  PRESIDENTIAL ELECTION CANDIDATES
# 1  2340          ELD                            PE2023
# 2  2305          ELD        PRESIDENTIAL ELECTION 2023
# 3  1637  NG KOK SONG        2023 PRESIDENTIAL ELECTION
# 4  1611  NG KOK SONG            PRESIDENTIAL ASPIRANTS
#
#                                          description weight rank links  \
# 0  Presidential election candidates work with ELD...    1.0   66     3
# 1  ELD revised the Registers of Electors for the ...    1.0   62     3
# 2  ELD revised the Registers of Electors for the ...    1.0   61     3
# 3  Ng Kok Song is a candidate for the 2023 Presid...    1.0  153     2
# 4  Ng Kok Song is one of the individuals running ...    1.0  149     2
#
#    in_context
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
result.context_data["reports"].head()
# Out:
#      id                                       title  \
# 0  2175        Presidential Candidates in Singapore
# 1   763  Singapore Presidential Election Candidates
#
#                                              content
# 0  # Presidential Candidates in Singapore\n\nThe ...
# 1  # Singapore Presidential Election Candidates\n...

# %%
result.context_data["sources"].head()
# Out:
#      id                                               text
# 0   694   Dr Walid said that so far, the three aspiring...
# 1    40   the previous election.\n\nPrior to every elec...
# 2  2909   noon, about 52 per cent, or 1,406,182 Singapo...
# 3  2618   adopt a positive, constructive, and open-mind...
# 4  1853   minister, chief justice, attorney-general or ...

# %% [markdown]
# ## Visualizing the result context as graph

# %%
"""
Helper function to visualize the result context with `yfiles-jupyter-graphs`.

The dataframes are converted into supported nodes and relationships lists and then passed to yfiles-jupyter-graphs.
Additionally, some values are mapped to visualization properties.
"""
def show_graph(result):
    """Visualize the result context with yfiles-jupyter-graphs."""
    from yfiles_jupyter_graphs import GraphWidget

    if (
        "entities" not in result.context_data
        or "relationships" not in result.context_data
    ):
        msg = "The passed results do not contain 'entities' or 'relationships'"
        raise ValueError(msg)

    # converts the entities dataframe to a list of dicts for yfiles-jupyter-graphs
    def convert_entities_to_dicts(df):
        """Convert the entities dataframe to a list of dicts for yfiles-jupyter-graphs."""
        nodes_dict = {}
        for _, row in df.iterrows():
            # Create a dictionary for each row and collect unique nodes
            node_id = row["entity"]
            if node_id not in nodes_dict:
                nodes_dict[node_id] = {
                    "id": node_id,
                    "properties": row.to_dict(),
                }
        return list(nodes_dict.values())

    # converts the relationships dataframe to a list of dicts for yfiles-jupyter-graphs
    def convert_relationships_to_dicts(df):
        """Convert the relationships dataframe to a list of dicts for yfiles-jupyter-graphs."""
        relationships = []
        for _, row in df.iterrows():
            # Create a dictionary for each row
            relationships.append({
                "start": row["source"],
                "end": row["target"],
                "properties": row.to_dict(),
            })
        return relationships

    w = GraphWidget()
    # use the converted data to visualize the graph
    w.nodes = convert_entities_to_dicts(result.context_data["entities"])
    w.edges = convert_relationships_to_dicts(result.context_data["relationships"])
    w.directed = True
    # show title on the node
    w.node_label_mapping = "entity"
    # use weight for edge thickness
    w.edge_thickness_factor_mapping = "weight"
    display(w)


show_graph(result)
# Out:
# GraphWidget(layout=Layout(height='700px', width='100%'))

# %%
import pandas as pd

# Another New Entity for "SINGAPORE'S PRESIDENTIAL ELECTION" with different details
another_new_entity_singapore_presidential = pd.DataFrame({
    'id': "453",  # Different ID to distinguish from the first entity
    'entity': ['THARMAN'],
    'description': ['Singapore\'s Presidential Hopeful and ex-PAP member.'],
    'number of relationships': [2],  # Initially no relationships, can be updated later
    'in_context': [True]
})

another_new_entity_singapore_presidential2 = pd.DataFrame({
    'id': "413",  # Different ID to distinguish from the first entity
    'entity': ['MONETARY AUTHORITY OF SINGAPORE'],
    'description': ['The Monetary Authority of Singapore or (MAS) is the central bank and financial regulatory authority of Singapore'],
    'number of relationships': [0],  # Initially no relationships, can be updated later
    'in_context': [True]
})

another_new_entity_singapore_presidential3 = pd.DataFrame({
    'id': "467",  # Different ID to distinguish from the first entity
    'entity': ['PEOPLE ACTION PARTY'],
    'description': ['The People\'s Action Party (PAP) is a political party of the centre-right in Singapore'],
    'number of relationships': [0],  # Initially no relationships, can be updated later
    'in_context': [True]
})


# New Relationship for the separate "SINGAPORE'S PRESIDENTIAL ELECTION" linked to "2023 PRESIDENTIAL ELECTION"
new_relationship_another_singapore_to_2023_1 = pd.DataFrame({
    'id': "358",  # A new ID for this relationship
    'source': ['THARMAN'],  # Source entity
    'target': ['NOMINATIONS'],  # Target entity
    'description': ['Tharman is a presidential candidate in the 2023 Presidential Elections'],
    'weight': [1.0],
    'links': [129],  # A new hypothetical link id
    'in_context': [True]
})

new_relationship_another_singapore_to_2023_2 = pd.DataFrame({
    'id': "561",  # A new ID for this relationship
    'source': ['MONETARY AUTHORITY OF SINGAPORE'],  # Source entity
    'target': ['THARMAN'],  # Target entity
    'description': ['Tharman was the chairman of MAS from 2011-2023'],
    'weight': [1.0],
    'links': [129],  
    'in_context': [True]
})


new_relationship_another_singapore_to_2023_3 = pd.DataFrame({
    'id': "261",  # A new ID for this relationship
    'source': ['PAP'],  # Source entity
    'target': ['THARMAN'],  # Target entity
    'description': ['Tharman former member of the governing People\'s Action Party (PAP), he was the Member of Parliament (MP) representing Jurong GRC between 2001 and 2023.'],
    'weight': [1.0],
    'links': [512],  
    'in_context': [True]
})


new_relationship_another_singapore_to_2023_4 = pd.DataFrame({
    'id': "321",  # A new ID for this relationship
    'source': ['PRESIDENTIAL CANDIDATES'],  # Source entity
    'target': ['PRESIDENTIAL ELECTION'],  # Target entity
    'description': ['Tharman is a presidential candidate in the 2023 Presidential Elections'],
    'weight': [1.0],
    'links': [875],  
    'in_context': [True]
})


result.context_data["relationships"] = pd.concat([
    result.context_data["relationships"], 
    new_relationship_another_singapore_to_2023_1,
    new_relationship_another_singapore_to_2023_2,
    new_relationship_another_singapore_to_2023_3,
    new_relationship_another_singapore_to_2023_4
], ignore_index=True)


result.context_data["entities"] = pd.concat([
    result.context_data["entities"], 
    another_new_entity_singapore_presidential,
    another_new_entity_singapore_presidential2,
    another_new_entity_singapore_presidential3,
    ], ignore_index=True)


show_graph(result)
# Out:
# /home/tjustin/.conda/envs/graphRag/lib/python3.10/site-packages/jupyter_client/session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# GraphWidget(layout=Layout(height='730px', width='100%'))
