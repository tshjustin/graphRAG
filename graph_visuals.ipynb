# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.indexer_adapters import (
    read_indexer_covariates,
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.input.loaders.dfs import (
    store_entity_semantic_embeddings,
)
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.embedding import OpenAIEmbedding
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.local_search.mixed_context import (
    LocalSearchMixedContext,
)
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore

# %% [markdown]
# ### Load text units and graph data tables as context for local search
#
# - In this test we first load indexing outputs from parquet files to dataframes, then convert these dataframes into collections of data objects aligning with the knowledge model.

# %% [markdown]
# ### Load tables to dataframes

# %%
INPUT_DIR = "/home/tjustin/ragtest/output/20240806-152635/artifacts"
LANCEDB_URI = f"{INPUT_DIR}/lancedb"

COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
RELATIONSHIP_TABLE = "create_final_relationships"
COVARIATE_TABLE = "create_final_covariates"
TEXT_UNIT_TABLE = "create_final_text_units"
COMMUNITY_LEVEL = 2

# %%
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")

entity_df
# Out:
#       level                   title          type  \
# 0         0              GEORGE GOH        PERSON
# 1         0     HARVEY NORMAN OSSIA  ORGANIZATION
# 2         0               SINGAPORE      LOCATION
# 3         0  THARMAN SHANMUGARATNAM        PERSON
# 4         0   INDEPENDENT CANDIDATE         GROUP
# ...     ...                     ...           ...
# 1423      2                ENTITIES         GROUP
# 1424      2           RELATIONSHIPS         GROUP
# 1425      2               TIMESTAMP     ATTRIBUTE
# 1426      2        CNA_3734106_IMG3        ENTITY
# 1427      2        CNA_3734106_IMG4        ENTITY
#
#                                             description  \
# 0     George Goh, a businessman and the founder of H...
# 1     Harvey Norman Ossia is a company founded by Ge...
# 2     Singapore is a country where various events, d...
# 3     Tharman Shanmugaratnam is a former Senior Mini...
# 4     The "INDEPENDENT CANDIDATE" is an individual r...
# ...                                                 ...
# 1423           Entities identified in the text document
# 1424        Relationships among the identified entities
# 1425  Timestamp indicating the date and time of the ...
# 1426       Specific identifier within the text document
# 1427       Specific identifier within the text document
#
#                                               source_id community  degree  \
# 0     226999648403d7b861f157424ef9d0dd,38b9800c055f3...         1      17
# 1     b82fff22533b0da06c9aac9c29dd6dd5,c8876e6c55219...         1       3
# 2     181424ccca876c684d29b92130e202e5,2a76cde17fc6d...        10      19
# 3     226999648403d7b861f157424ef9d0dd,295c7a9c9182e...         7      19
# 4     0d9dfafad762b3663c21595e561fbd5e,c8876e6c55219...         1       2
# ...                                                 ...       ...     ...
# 1423                   33aba9b9b3839b41e12291338e195321      None       1
# 1424                   33aba9b9b3839b41e12291338e195321      None       1
# 1425                   33aba9b9b3839b41e12291338e195321      None       1
# 1426                   33aba9b9b3839b41e12291338e195321      None       1
# 1427                   33aba9b9b3839b41e12291338e195321      None       1
#
#       human_readable_id                                id  size  \
# 0                     0  b45241d70f0e43fca764df95b2b81f77    17
# 1                     1  4119fd06010c494caa07f439b333f4c5     3
# 2                     2  d3835bf3dda84ead99deadbeac5d0d7d    19
# 3                     3  077d2820ae1845bcbb1803379a3d1eae    19
# 4                     4  3671ea0dd4e84c1a9b02c5ab2c8f4bac     2
# ...                 ...                               ...   ...
# 1423                471  1f7b02bf486e4f42b23e9cb1a63207f3     1
# 1424                472  e744c118ae7f4638a01d060bbaedd6e9     1
# 1425                473  e1c1080c717d437996def1a41772d179     1
# 1426                474  63fba9a7c47a4f14ac0bee6bc90d0fea     1
# 1427                475  6bfc2395b4f54a528a1ebac94a43acb8     1
#
#      graph_embedding                 top_level_node_id  x  y
# 0               None  b45241d70f0e43fca764df95b2b81f77  0  0
# 1               None  4119fd06010c494caa07f439b333f4c5  0  0
# 2               None  d3835bf3dda84ead99deadbeac5d0d7d  0  0
# 3               None  077d2820ae1845bcbb1803379a3d1eae  0  0
# 4               None  3671ea0dd4e84c1a9b02c5ab2c8f4bac  0  0
# ...              ...                               ... .. ..
# 1423            None  1f7b02bf486e4f42b23e9cb1a63207f3  0  0
# 1424            None  e744c118ae7f4638a01d060bbaedd6e9  0  0
# 1425            None  e1c1080c717d437996def1a41772d179  0  0
# 1426            None  63fba9a7c47a4f14ac0bee6bc90d0fea  0  0
# 1427            None  6bfc2395b4f54a528a1ebac94a43acb8  0  0
#
# [1428 rows x 14 columns]

# %% [markdown]
# #### Read entities - embedding

# %%
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

entity_embedding_df
# Out:
#                                    id                    name          type  \
# 0    b45241d70f0e43fca764df95b2b81f77              GEORGE GOH        PERSON
# 1    4119fd06010c494caa07f439b333f4c5     HARVEY NORMAN OSSIA  ORGANIZATION
# 2    d3835bf3dda84ead99deadbeac5d0d7d               SINGAPORE      LOCATION
# 3    077d2820ae1845bcbb1803379a3d1eae  THARMAN SHANMUGARATNAM        PERSON
# 4    3671ea0dd4e84c1a9b02c5ab2c8f4bac   INDEPENDENT CANDIDATE         GROUP
# ..                                ...                     ...           ...
# 233  1f7b02bf486e4f42b23e9cb1a63207f3                ENTITIES         GROUP
# 234  e744c118ae7f4638a01d060bbaedd6e9           RELATIONSHIPS         GROUP
# 235  e1c1080c717d437996def1a41772d179               TIMESTAMP     ATTRIBUTE
# 236  63fba9a7c47a4f14ac0bee6bc90d0fea        CNA_3734106_IMG3        ENTITY
# 237  6bfc2395b4f54a528a1ebac94a43acb8        CNA_3734106_IMG4        ENTITY
#
#                                            description  human_readable_id  \
# 0    George Goh, a businessman and the founder of H...                  0
# 1    Harvey Norman Ossia is a company founded by Ge...                  1
# 2    Singapore is a country where various events, d...                  2
# 3    Tharman Shanmugaratnam is a former Senior Mini...                  3
# 4    The "INDEPENDENT CANDIDATE" is an individual r...                  4
# ..                                                 ...                ...
# 233           Entities identified in the text document                471
# 234        Relationships among the identified entities                472
# 235  Timestamp indicating the date and time of the ...                473
# 236       Specific identifier within the text document                474
# 237       Specific identifier within the text document                475
#
#     graph_embedding                                      text_unit_ids  \
# 0              None  [226999648403d7b861f157424ef9d0dd, 38b9800c055...
# 1              None  [b82fff22533b0da06c9aac9c29dd6dd5, c8876e6c552...
# 2              None  [181424ccca876c684d29b92130e202e5, 2a76cde17fc...
# 3              None  [226999648403d7b861f157424ef9d0dd, 295c7a9c918...
# 4              None  [0d9dfafad762b3663c21595e561fbd5e, c8876e6c552...
# ..              ...                                                ...
# 233            None                 [33aba9b9b3839b41e12291338e195321]
# 234            None                 [33aba9b9b3839b41e12291338e195321]
# 235            None                 [33aba9b9b3839b41e12291338e195321]
# 236            None                 [33aba9b9b3839b41e12291338e195321]
# 237            None                 [33aba9b9b3839b41e12291338e195321]
#
#                                  description_embedding
# 0    [-0.017695769667625427, 0.017364203929901123, ...
# 1    [-0.009658072143793106, 0.036502767354249954, ...
# 2    [-0.0038641251157969236, 0.0012783686397597194...
# 3    [-0.020518304780125618, -0.021766113117337227,...
# 4    [0.009030026383697987, -0.021186936646699905, ...
# ..                                                 ...
# 233  [-0.018409516662359238, 0.04041050374507904, 0...
# 234  [-0.005274868570268154, -0.013643065467476845,...
# 235  [-0.018489323556423187, 0.02154754474759102, 0...
# 236  [0.009851847775280476, 0.024521438404917717, 0...
# 237  [0.01095021516084671, 0.02748006582260132, 0.0...
#
# [476 rows x 8 columns]

# %% [markdown]
# #### Read relationships

# %%
relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
relationships = read_indexer_relationships(relationship_df)

relationships
# Out:
# [Relationship(id='1cce5cebf437428eb1a60dffbdfa603f', short_id='0', source='GEORGE GOH', target='HARVEY NORMAN OSSIA', weight=1.0, description='George Goh is the founder of Harvey Norman Ossia', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='dc94039d6643460ca3c66150b9087129', short_id='1', source='GEORGE GOH', target='SINGAPORE', weight=1.0, description='George Goh is running for the Singapore presidency', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 36}),
#  Relationship(id='f197d75f159943f8a3ff441199790bc7', short_id='2', source='GEORGE GOH', target='INDEPENDENT CANDIDATE', weight=1.0, description='George Goh is contesting as an independent candidate', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='4d8890c699684c9381105b03b0b41b03', short_id='3', source='GEORGE GOH', target='ENTREPRENEUR', weight=1.0, description='George Goh is an entrepreneur who started working at a young age', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='b1658adfa43847eabad1437db235e858', short_id='4', source='GEORGE GOH', target='OSSIA INTERNATIONAL', weight=1.0, description='George Goh chairs Ossia International', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='a1773cac7d4c4939aec965660e5015fe', short_id='5', source='GEORGE GOH', target='BORDER MISSION', weight=1.0, description='George Goh co-founded Border Mission', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='6a054cb59fb44cf494b93988b5f88833', short_id='6', source='GEORGE GOH', target='RED CROSS SOCIETY', weight=1.0, description='George Goh serves as a council member at Red Cross Society', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='e7b103a52e384e3e8bf14105223e7e82', short_id='7', source='GEORGE GOH', target='NON-RESIDENT AMBASSADOR', weight=1.0, description="George Goh was appointed as Singapore's non-resident ambassador to Morocco", description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 18}),
#  Relationship(id='3f1042452c254cecaf7189e89162adc8', short_id='8', source='GEORGE GOH', target='MINISTRY OF FOREIGN AFFAIRS', weight=1.0, description='George Goh tendered his resignation to the Ministry of Foreign Affairs', description_embedding=None, text_unit_ids=['c8876e6c55219846d1bd69e2de1dbba6'], document_ids=None, attributes={'rank': 19}),
#  Relationship(id='fd31d549420744d1bd1a6b1112a9a6ba', short_id='9', source='GEORGE GOH', target='CERTIFICATES OF ELIGIBILITY', weight=1.0, description='George Goh did not receive a Certificate of Eligibility', description_embedding=None, text_unit_ids=['226999648403d7b861f157424ef9d0dd'], document_ids=None, attributes={'rank': 23}),
#  Relationship(id='f7ab348030714072a277682b51f7c588', short_id='10', source='GEORGE GOH', target='TAN KIN LIAN', weight=1.0, description='George Goh and Tan Kin Lian are both presidential hopefuls', description_embedding=None, text_unit_ids=['38b9800c055f3bfbaf59149b1cca46eb'], document_ids=None, attributes={'rank': 60}),
#  Relationship(id='2139b0906dc541e094138a978d070416', short_id='11', source='GEORGE GOH', target='ELIGIBILITY CRITERIA', weight=1.0, description='George Goh must meet eligibility criteria to qualify for the Presidential Election', description_embedding=None, text_unit_ids=['38b9800c055f3bfbaf59149b1cca46eb'], document_ids=None, attributes={'rank': 18}),
#  Relationship(id='ff5466607e5d4453b1d833629292f664', short_id='12', source='GEORGE GOH', target='REPORTERS', weight=1.0, description='George Goh spoke to reporters regarding his candidacy', description_embedding=None, text_unit_ids=['38b9800c055f3bfbaf59149b1cca46eb'], document_ids=None, attributes={'rank': 25}),
#  Relationship(id='71f95003936e46a98d90757ffd845d40', short_id='13', source='GEORGE GOH', target='YOUTHS', weight=1.0, description='George Goh engaged in a dialogue session with youths', description_embedding=None, text_unit_ids=['38b9800c055f3bfbaf59149b1cca46eb'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='bada987ea7da4c939393ee1c3d08ccd4', short_id='14', source='GEORGE GOH', target='CIO', weight=1.0, description='George Goh made a mistake about the role of CIO in an investment management company', description_embedding=None, text_unit_ids=['46ad0b078ea15b9b9c240a432e1ce099'], document_ids=None, attributes={'rank': 25}),
#  Relationship(id='d0a274e7934d446fb91847bb53a961a6', short_id='15', source='GEORGE GOH', target='COMMENTS', weight=1.0, description='George Goh made comments about the CIO role', description_embedding=None, text_unit_ids=['46ad0b078ea15b9b9c240a432e1ce099'], document_ids=None, attributes={'rank': 18}),
#  Relationship(id='0a799eab61bc4e6b884db6689f9c2c4a', short_id='16', source='GEORGE GOH', target='PRESS CONFERENCE', weight=1.0, description='George Goh made comments at a press conference', description_embedding=None, text_unit_ids=['46ad0b078ea15b9b9c240a432e1ce099'], document_ids=None, attributes={'rank': 18}),
#  Relationship(id='8c34cd494a63438dac219c1dc0f73100', short_id='17', source='HARVEY NORMAN OSSIA', target='MR GOH', weight=1.0, description='Mr Goh is the founder of Harvey Norman Ossia', description_embedding=None, text_unit_ids=['b82fff22533b0da06c9aac9c29dd6dd5'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='c6f428af0c5e4f629902fd5455bf19ac', short_id='18', source='HARVEY NORMAN OSSIA', target='MR. GOH', weight=1.0, description='Mr. Goh is the founder of Harvey Norman Ossia', description_embedding=None, text_unit_ids=['fd67ba716e41fbd474b156965549503e'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='d1fd271d16c348019c2fcced762b35a2', short_id='19', source='SINGAPORE', target='RESERVES', weight=1.0, description='The discussions on drawing down reserves took place in Singapore', description_embedding=None, text_unit_ids=['2a76cde17fc6dd135067974e2cc8986e'], document_ids=None, attributes={'rank': 34}),
#  Relationship(id='ffa128c9c0c84d39bad1bba8cfa4adc5', short_id='20', source='SINGAPORE', target='COVID-19', weight=1.0, description='Singapore is facing the global crisis of COVID-19', description_embedding=None, text_unit_ids=['f0e7f7ffaeb43ee816b649c53380c58c'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='058f66cc356b43cc9433bd3c8d57fa46', short_id='21', source='SINGAPORE', target='SARS', weight=1.0, description='Singapore had experience with a similar crisis of SARS', description_embedding=None, text_unit_ids=['f0e7f7ffaeb43ee816b649c53380c58c'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='ff74091eaba246698fcae59c21eec828', short_id='22', source='SINGAPORE', target='HALIMAH YACOB', weight=1.0, description='Halimah Yacob served as the President of Singapore', description_embedding=None, text_unit_ids=['cdf1d9c993dee233902996d2e817c7f6'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='f6cbbf1b8f4b48a28a16e4dd8976b9bb', short_id='23', source='SINGAPORE', target='GLOBAL LEADERS', weight=1.0, description='Singapore interacts with global leaders in various discussions', description_embedding=None, text_unit_ids=['62eabd6efbeb685dae854f741696f82d'], document_ids=None, attributes={'rank': 24}),
#  Relationship(id='757ca40654d5476aa949a26b733be8d4', short_id='24', source='SINGAPORE', target='KING SALMAN BIN ABDULAZIZ AL SAUD', weight=1.0, description='Singapore was mentioned in relation to King Salman bin Abdulaziz Al Saud', description_embedding=None, text_unit_ids=['56992df67094586a03bde6ff25176de9'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='539d55e7c42e44b59d98f59fae3e0ee1', short_id='25', source='SINGAPORE', target='KAZAKHSTAN', weight=1.0, description='Singapore and Kazakhstan were visited by the first head of state', description_embedding=None, text_unit_ids=['56992df67094586a03bde6ff25176de9'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='3785eeadea9042bfb2e50f16c0397a12', short_id='26', source='SINGAPORE', target='UZBEKISTAN', weight=1.0, description='Singapore and Uzbekistan were visited by the first head of state', description_embedding=None, text_unit_ids=['56992df67094586a03bde6ff25176de9'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='48cd97f2297143e09d61ff2a8542c0c5', short_id='27', source='SINGAPORE', target='GERMANY', weight=1.0, description='Singapore and Germany were visited by the first head of state', description_embedding=None, text_unit_ids=['56992df67094586a03bde6ff25176de9'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='ff95eb0d5f7f49b782027d5c7ae3c3fe', short_id='28', source='SINGAPORE', target='NETHERLANDS', weight=1.0, description='Singapore and Netherlands were visited by the first head of state', description_embedding=None, text_unit_ids=['56992df67094586a03bde6ff25176de9'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='086da554db5b4ad5806aedeb0024197c', short_id='29', source='SINGAPORE', target='CHINA', weight=1.0, description='Singapore and China have a very good relationship', description_embedding=None, text_unit_ids=['56992df67094586a03bde6ff25176de9'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='216ee8a907a0466a88b27f8ada19ffa0', short_id='30', source='SINGAPORE', target='GIC', weight=1.0, description="GIC is Singapore's sovereign wealth fund", description_embedding=None, text_unit_ids=['fd67ba716e41fbd474b156965549503e'], document_ids=None, attributes={'rank': 26}),
#  Relationship(id='6fefb317687d4ac98efe39a52f3e190f', short_id='31', source='SINGAPORE', target='SINGAPOREANS', weight=1.0, description='Singaporeans are feeling the pain of the higher cost of living in Singapore', description_embedding=None, text_unit_ids=['fd67ba716e41fbd474b156965549503e'], document_ids=None, attributes={'rank': 25}),
#  Relationship(id='320d9d91238948a8be67972ccceab878', short_id='32', source='SINGAPORE', target='NG', weight=2.0, description="SINGAPORE is currently holding an election, and one of the candidates running is Mr Ng. It is important for NG's supporters to be physically present in Singapore to show their support.", description_embedding=None, text_unit_ids=['181424ccca876c684d29b92130e202e5', '60dbaac086f3ecf1fffc5d0149e62f26'], document_ids=None, attributes={'rank': 76}),
#  Relationship(id='bdcbcccadd474b3bbe9a8f56c811bab4', short_id='33', source='SINGAPORE', target='ASSENTERS', weight=1.0, description='Assenters need to be physically present in Singapore', description_embedding=None, text_unit_ids=['5fae166b57b9e30d3af2597400b8bd79'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='f127fc4d87f94794be89134406ba0694', short_id='34', source='SINGAPORE', target='THARMAN', weight=1.0, description="Tharman is running to become Singapore's head of state", description_embedding=None, text_unit_ids=['afafeb7bc3059dadb6df9621d2287252'], document_ids=None, attributes={'rank': 46}),
#  Relationship(id='c27966a4e3be434686454204ac7b3ab4', short_id='35', source='SINGAPORE', target='PRESIDENTIAL ELECTION', weight=1.0, description='The Presidential Election is happening in Singapore', description_embedding=None, text_unit_ids=['2d7132d240dba2916e7eef851577ff4c'], document_ids=None, attributes={'rank': 35}),
#  Relationship(id='dab39f92d0ed468c80699f28c05c45fa', short_id='36', source='SINGAPORE', target='BALLOT BOX', weight=2.0, description='SINGAPORE, a country in Southeast Asia, will have its citizens cast their votes in the BALLOT BOX during the upcoming Presidential Election. This indicates a democratic process where Singaporeans participate in choosing their leader through voting.', description_embedding=None, text_unit_ids=['2d7132d240dba2916e7eef851577ff4c', 'b7a70ee9f87e39ff84ec460b57ef010e'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='3076f330d121489aa50964ce54a3b1ac', short_id='37', source='THARMAN SHANMUGARATNAM', target='PRESIDENTIAL ELECTION', weight=4.0, description='Tharman Shanmugaratnam is a potential candidate for the Presidential Election.', description_embedding=None, text_unit_ids=['5625cbd7b0e657826e6dba0413256b7f', 'e8522f903cb3b857b4e70a9208285729', 'ef304a8cba159d90b1f60c49d2722dc6'], document_ids=None, attributes={'rank': 35}),
#  Relationship(id='c8e5d3afdcb54c8589e280f0c4a87417', short_id='38', source='THARMAN SHANMUGARATNAM', target='PEOPLES ACTION PARTY', weight=1.0, description='Tharman Shanmugaratnam has been associated with the Peoples Action Party since 2001', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='f3d30627e19245649e497ab49bf0fa30', short_id='39', source='THARMAN SHANMUGARATNAM', target='CABINET MINISTER', weight=1.0, description='Tharman Shanmugaratnam has been a Cabinet Minister involved in public finance policies', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='e3f1098c3d984bc7b5f30b9c0101f7a6', short_id='40', source='THARMAN SHANMUGARATNAM', target='INSTITUTIONS', weight=1.0, description='Tharman Shanmugaratnam has been closely involved with institutions', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='24b4a5f4db67418cbfa08c5316f0ab51', short_id='41', source='THARMAN SHANMUGARATNAM', target='GOVERNMENT', weight=1.0, description='Tharman Shanmugaratnam has been associated with the government', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 30}),
#  Relationship(id='e4b707e3e6964197855b82fc66ef59e7', short_id='42', source='THARMAN SHANMUGARATNAM', target='PE 2023', weight=2.0, description='Tharman Shanmugaratnam is one of the candidates for the Presidential Election', description_embedding=None, text_unit_ids=['eec850fa03ffcacc5639e3fbb4a8d35e', 'f24cce47f9d0745c4a3bed896da6aedd'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='109b8be5a8ee4180a1465cd23f019d7b', short_id='43', source='THARMAN SHANMUGARATNAM', target='CERTIFICATES OF ELIGIBILITY', weight=1.0, description='Tharman Shanmugaratnam received a Certificate of Eligibility', description_embedding=None, text_unit_ids=['226999648403d7b861f157424ef9d0dd'], document_ids=None, attributes={'rank': 25}),
#  Relationship(id='49f771e31a0c4b35bc39e389f3623509', short_id='44', source='THARMAN SHANMUGARATNAM', target='NG KOK SONG', weight=4.0, description="Tharman Shanmugaratnam and Ng Kok Song are both presidential hopefuls for the upcoming Presidential Election. Ng Kok Song has conceded defeat to Tharman Shanmugaratnam, who is also a potential candidate in the election. However, Ng Kok Song has criticized Tharman Shanmugaratnam's views on independence. The competition between these two candidates is heating up as they vie for the presidency.", description_embedding=None, text_unit_ids=['295c7a9c9182e80ed8d86b4c66ac4f65', '342daee69baadbd58b982b210b004668', '3edad8ac208c537fa584c626de39857f', 'da986516378fdf0625ca5eeb1916788d'], document_ids=None, attributes={'rank': 52}),
#  Relationship(id='aa946d4379694a74ba0da37e69d2810a', short_id='45', source='THARMAN SHANMUGARATNAM', target='HALIMAH', weight=2.0, description='Tharman Shanmugaratnam will succeed Halimah as the next President of Singapore.', description_embedding=None, text_unit_ids=['72f8f272e47d85878d673e956511ade1', 'e2cc6cd906b8870e82750207abc807f5'], document_ids=None, attributes={'rank': 47}),
#  Relationship(id='268446fc52a54fd2837f73aeb3e0b74f', short_id='46', source='THARMAN SHANMUGARATNAM', target='SEP 13', weight=1.0, description='Tharman Shanmugaratnam will be sworn in as President after Sep 13', description_embedding=None, text_unit_ids=['62eabd6efbeb685dae854f741696f82d'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='f6ddfa8491ff40d2839bb5b2e105df22', short_id='47', source='THARMAN SHANMUGARATNAM', target='MR GOH', weight=1.0, description='Mr Goh and Tharman Shanmugaratnam are both candidates for the upcoming Presidential Election', description_embedding=None, text_unit_ids=['b82fff22533b0da06c9aac9c29dd6dd5'], document_ids=None, attributes={'rank': 45}),
#  Relationship(id='db1295504da645b69d9786d54f233fed', short_id='48', source='THARMAN SHANMUGARATNAM', target='POLICYMAKER', weight=1.0, description='Tharman Shanmugaratnam is described as a policymaker', description_embedding=None, text_unit_ids=['f7918bc5f63873cebe4683a8b16482db'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='6ff4ed0dda4f4158af37be99f505565f', short_id='49', source='THARMAN SHANMUGARATNAM', target="PEOPLE'S ACTION PARTY", weight=1.0, description="Tharman Shanmugaratnam was a former member of the People's Action Party", description_embedding=None, text_unit_ids=['342daee69baadbd58b982b210b004668'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='5d398b88ee4242a59c32feb188683ec3', short_id='50', source='THARMAN SHANMUGARATNAM', target='CONSTITUTION', weight=1.0, description='Tharman Shanmugaratnam refutes claims of not adhering to the Constitution', description_embedding=None, text_unit_ids=['342daee69baadbd58b982b210b004668'], document_ids=None, attributes={'rank': 24}),
#  Relationship(id='0a784e00c9464bd3aeb830b908f73170', short_id='51', source='THARMAN SHANMUGARATNAM', target='CNA', weight=1.0, description='Tharman Shanmugaratnam participated in a forum hosted by CNA', description_embedding=None, text_unit_ids=['342daee69baadbd58b982b210b004668'], document_ids=None, attributes={'rank': 24}),
#  Relationship(id='b0966a0f455e44229e6c9705d57bfca9', short_id='52', source='THARMAN SHANMUGARATNAM', target='NG', weight=1.0, description="Ng responds to Tharman's comments", description_embedding=None, text_unit_ids=['4bee639f313bcf5d8fc312f4e624a465'], document_ids=None, attributes={'rank': 76}),
#  Relationship(id='99761e9b89cc4060be3ed6b34532e7ff', short_id='53', source='THARMAN SHANMUGARATNAM', target='PRESIDENTIAL FORUM', weight=1.0, description='Tharman makes comments during the presidential forum', description_embedding=None, text_unit_ids=['4bee639f313bcf5d8fc312f4e624a465'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='8130a1a82bde46048952cf147690e630', short_id='54', source='THARMAN SHANMUGARATNAM', target='ONG TENG CHEONG', weight=1.0, description='Tharman mentions Ong Teng Cheong as a past candidate', description_embedding=None, text_unit_ids=['4bee639f313bcf5d8fc312f4e624a465'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='79c99026b7ef4946b9b8e0be841fd4c5', short_id='55', source='THARMAN SHANMUGARATNAM', target='DR TONY TAN', weight=1.0, description='Tharman mentions Dr Tony Tan as a past candidate', description_embedding=None, text_unit_ids=['4bee639f313bcf5d8fc312f4e624a465'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='fdcb1673254842f1935f53d0c38c467e', short_id='56', source='INDEPENDENT CANDIDATE', target='MR GOH', weight=1.0, description='Mr Goh describes himself as an independent candidate', description_embedding=None, text_unit_ids=['0d9dfafad762b3663c21595e561fbd5e'], document_ids=None, attributes={'rank': 28}),
#  Relationship(id='dcb3f4cc8abc46faabc193d9885e91d0', short_id='57', source='ENTREPRENEUR', target='CERTIFICATE OF ELIGIBILITY', weight=1.0, description='Entrepreneurs must prepare materials for success, including certificates', description_embedding=None, text_unit_ids=['0d9dfafad762b3663c21595e561fbd5e'], document_ids=None, attributes={'rank': 18}),
#  Relationship(id='3295be59128d451bb720c6688adc1e0b', short_id='58', source='OSSIA INTERNATIONAL', target='PRIVATE SECTOR CANDIDATES', weight=1.0, description='The individual is associated with Ossia International', description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 9}),
#  Relationship(id='aca3eb8924ac494486fe0bfe892f7f2e', short_id='59', source='BORDER MISSION', target='PRIVATE SECTOR CANDIDATES', weight=1.0, description='The individual co-founded Border Mission', description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 9}),
#  Relationship(id='66689accdd974295b7eb779e43578748', short_id='60', source='RED CROSS SOCIETY', target='PRIVATE SECTOR CANDIDATES', weight=1.0, description='The individual serves as a council member at Red Cross Society', description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 9}),
#  Relationship(id='6b49c78aa1524609ab7aa74aeaa3e01d', short_id='61', source='MINISTRY OF FOREIGN AFFAIRS', target='PRIVATE SECTOR CANDIDATES', weight=1.0, description='The individual tendered his resignation to the Ministry of Foreign Affairs', description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 9}),
#  Relationship(id='7ff31ce54f424f0bbb297b0b3ba7c757', short_id='62', source='NON-RESIDENT AMBASSADOR TO MOROCCO', target='PRIVATE SECTOR CANDIDATES', weight=1.0, description="The individual was appointed as Singapore's non-resident ambassador to Morocco", description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 8}),
#  Relationship(id='bac51e00d486420c8e91e824d8e17411', short_id='63', source='PRESIDENT HALIMAH YACOB', target='PRESIDENTIAL ELECTION', weight=1.0, description='Halimah Yacob is the current President during the upcoming Presidential Election', description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='4adee3aad6524a4aa4c4711c1ee05e64', short_id='64', source='ELECTIONS DEPARTMENT', target='PRESIDENTIAL ELECTION', weight=1.0, description='The Elections Department is responsible for organizing the upcoming Presidential Election', description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 20}),
#  Relationship(id='d034e4fd8ac849278e658daad1a1f033', short_id='65', source='ELECTIONS DEPARTMENT', target='CERTIFICATES OF ELIGIBILITY', weight=1.0, description='The Elections Department issues Certificates of Eligibility', description_embedding=None, text_unit_ids=['226999648403d7b861f157424ef9d0dd'], document_ids=None, attributes={'rank': 10}),
#  Relationship(id='091e998370dd42d1b05ab0fcf6595a7e', short_id='66', source='ELECTIONS DEPARTMENT', target='COMMUNITY DECLARATION', weight=1.0, description='The Elections Department oversees the Community Declaration process', description_embedding=None, text_unit_ids=['226999648403d7b861f157424ef9d0dd'], document_ids=None, attributes={'rank': 8}),
#  Relationship(id='1e6cabc18fab4c048281fd29d3044438', short_id='67', source='ELECTIONS DEPARTMENT', target='NG KOK SONG', weight=1.0, description='Ng Kok Song expresses confidence in the Elections Department', description_embedding=None, text_unit_ids=['221fe52bc4190a21299f7e686ac01b4b'], document_ids=None, attributes={'rank': 37}),
#  Relationship(id='dc08f6d7398b4b798a3bdccf508a2ad4', short_id='68', source='PRESIDENTIAL ELECTION', target='MR GOH', weight=1.0, description='Mr Goh is a candidate for the Presidential Election', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 42}),
#  Relationship(id='1c7fd5af8d8041e186eae2431fc627cd', short_id='69', source='PRESIDENTIAL ELECTION', target='PRIVATE SECTOR CANDIDATES', weight=1.0, description='Private sector candidates are eligible to run for the Presidential Election', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 23}),
#  Relationship(id='b16eda56dcec40f2b3e109fb9246bee3', short_id='70', source='PRESIDENTIAL ELECTION', target='PRESIDENT MADAM HALIMAH YACOB', weight=1.0, description='President Madam Halimah Yacob was a past President', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='43c68f9a86654a32a2215e23957ed184', short_id='71', source='PRESIDENTIAL ELECTION', target='NATIONAL RESERVES', weight=1.0, description='The President plays a role in managing the national reserves', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='1ba06fe2e86140a59bbc4f4e969d0f71', short_id='72', source='PRESIDENTIAL ELECTION', target='PUBLIC OFFICE APPOINTMENTS', weight=1.0, description='The President is involved in key public office appointments', description_embedding=None, text_unit_ids=['e8522f903cb3b857b4e70a9208285729'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='36caa0a230c8422c8acb4dc62e35bb32', short_id='73', source='PRESIDENTIAL ELECTION', target='CERTIFICATE OF ELIGIBILITY', weight=1.0, description='Candidates need to apply for a Certificate of Eligibility to enter the Presidential Election', description_embedding=None, text_unit_ids=['e258a2f6f582f26433e7ee6ab285a0bd'], document_ids=None, attributes={'rank': 32}),
#  Relationship(id='09940fed9d154504948bba2df1789a50', short_id='74', source='PRESIDENTIAL ELECTION', target='MR NG', weight=1.0, description="Mr Ng's goal was to ensure Singaporeans could vote in the Presidential Election", description_embedding=None, text_unit_ids=['23bdaf475083cb17fd0392ad0717475f'], document_ids=None, attributes={'rank': 44}),
#  Relationship(id='4d6608557eed49368a6d09c7c5c664c5', short_id='75', source='PRESIDENTIAL ELECTION', target='NG', weight=1.0, description='Ng is a potential candidate for the Presidential Election', description_embedding=None, text_unit_ids=['5625cbd7b0e657826e6dba0413256b7f'], document_ids=None, attributes={'rank': 73}),
#  Relationship(id='eb7c93eeb9dc41aab57d29e97ebb4951', short_id='76', source='PRESIDENTIAL ELECTION', target='TAN KIN LIAN', weight=3.0, description='Tan Kin Lian is a potential candidate for the Presidential Election.', description_embedding=None, text_unit_ids=['5625cbd7b0e657826e6dba0413256b7f', 'ef304a8cba159d90b1f60c49d2722dc6'], document_ids=None, attributes={'rank': 59}),
#  Relationship(id='3b6e2ac584b64847b53828c9d779fed3', short_id='77', source='PRESIDENTIAL ELECTION', target='POLLS', weight=1.0, description='If the election is contested, Singapore will go to the polls on Sept 1', description_embedding=None, text_unit_ids=['5625cbd7b0e657826e6dba0413256b7f'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='e9b68002e035447baae848208cea5503', short_id='78', source='PRESIDENTIAL ELECTION', target='NG KOK SONG', weight=1.0, description='Ng Kok Song is a candidate for the Presidential Election', description_embedding=None, text_unit_ids=['ef304a8cba159d90b1f60c49d2722dc6'], document_ids=None, attributes={'rank': 49}),
#  Relationship(id='fe18353546824ca98294ce4be7b96e02', short_id='79', source='PRESIDENTIAL ELECTION', target='COOLING-OFF DAY', weight=1.0, description='Cooling-off Day precedes the Presidential Election', description_embedding=None, text_unit_ids=['2d7132d240dba2916e7eef851577ff4c'], document_ids=None, attributes={'rank': 18}),
#  Relationship(id='0e9740e25f5a460c81318336e00ac880', short_id='80', source='PRIVATE SECTOR CANDIDATES', target='ELIGIBILITY REQUIREMENT', weight=1.0, description='The eligibility requirement for private sector candidates was raised in 2017', description_embedding=None, text_unit_ids=['a3bd0c5e863f9c23f1c6925b169dbee6'], document_ids=None, attributes={'rank': 8}),
#  Relationship(id='b7cd9a62710849778fdadced0d754687', short_id='81', source='MR GOH', target='MR THARMAN', weight=1.0, description="Mr Goh questions Mr Tharman's suitability for the Presidency", description_embedding=None, text_unit_ids=['e258a2f6f582f26433e7ee6ab285a0bd'], document_ids=None, attributes={'rank': 47}),
#  Relationship(id='432a6b4962544200949421a96a405142', short_id='82', source='MR GOH', target='MR TAN', weight=2.0, description='Mr Goh and Mr Tan are both candidates and presidential hopefuls for the upcoming Presidential Election. They are individuals vying for the same position, indicating a competitive race between the two. The timestamp of the information is not provided.', description_embedding=None, text_unit_ids=['3edad8ac208c537fa584c626de39857f', 'b82fff22533b0da06c9aac9c29dd6dd5'], document_ids=None, attributes={'rank': 40}),
#  Relationship(id='d6700b360ac141d282cdb567414bf4ce', short_id='83', source='MR GOH', target='REPORTERS', weight=1.0, description='Mr Goh spoke to reporters about his candidacy and eligibility criteria', description_embedding=None, text_unit_ids=['b82fff22533b0da06c9aac9c29dd6dd5'], document_ids=None, attributes={'rank': 34}),
#  Relationship(id='c1b40a4039b44061a358e098867f7412', short_id='84', source='MR GOH', target='YOUTHS', weight=1.0, description='Mr Goh had a dialogue session with a group of youths', description_embedding=None, text_unit_ids=['b82fff22533b0da06c9aac9c29dd6dd5'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='4643a7a319674adfb732b6f6122c7c64', short_id='85', source='MR GOH', target='PRIVATE SECTOR', weight=2.0, description='MR GOH is actively involved in the private sector, aiming to qualify under the "deliberative track." This indicates that Mr Goh is closely associated with private sector activities and initiatives.', description_embedding=None, text_unit_ids=['8183d9c29fa8e5548d05a25385bd5469', 'b82fff22533b0da06c9aac9c29dd6dd5'], document_ids=None, attributes={'rank': 28}),
#  Relationship(id='46e8056fb2ec4811ab33cb34a0dc9fb3', short_id='86', source='MR GOH', target='NG KOK SONG', weight=2.0, description='Both Mr Goh and Ng Kok Song are candidates and presidential hopefuls for the upcoming Presidential Election. They are actively participating in the election process and are vying for the position of President. The timestamp of the articles related to their candidacy is crucial for understanding the progression of their campaigns and the dynamics within the political landscape.', description_embedding=None, text_unit_ids=['3edad8ac208c537fa584c626de39857f', 'b82fff22533b0da06c9aac9c29dd6dd5'], document_ids=None, attributes={'rank': 59}),
#  Relationship(id='8b57a9f43a1942a49b58cf881835f974', short_id='87', source='MR GOH', target='CAMPAIGN', weight=1.0, description='Mr Goh launched his platform and slogan for his campaign', description_embedding=None, text_unit_ids=['8183d9c29fa8e5548d05a25385bd5469'], document_ids=None, attributes={'rank': 28}),
#  Relationship(id='f78b01b0d93948c283644ec58f7be74a', short_id='88', source='MR GOH', target='VALUES', weight=1.0, description='Mr Goh aims to achieve specific values in his campaign', description_embedding=None, text_unit_ids=['8183d9c29fa8e5548d05a25385bd5469'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='8dbe8f9867e4448f998416c18923eac4', short_id='89', source='MR GOH', target='ANNUAL REPORT CARD', weight=2.0, description='Mr Goh plans to introduce an annual report card if elected', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12', '8183d9c29fa8e5548d05a25385bd5469'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='fe8ea8bf1395434393e04e8f7a33025f', short_id='90', source='MR GOH', target="PRESIDENT'S CHALLENGE", weight=2.0, description="MR GOH aims to enlarge and deepen the impact of the President's Challenge if elected. He intends to enhance the President's Challenge, showing a commitment to improving and expanding the organization's reach and effectiveness.", description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12', '8183d9c29fa8e5548d05a25385bd5469'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='7d58b089bfc549e8951e91ad62541119', short_id='91', source='MR GOH', target='PHILANTHROPIC EXPERIENCE', weight=1.0, description='Mr Goh will utilize his philanthropic experience for fundraising', description_embedding=None, text_unit_ids=['8183d9c29fa8e5548d05a25385bd5469'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='1fa6d3118bd846c8837b5fa9fb78f262', short_id='92', source='MR GOH', target='BUSINESS NETWORK', weight=1.0, description='Mr Goh will leverage his business network for fundraising', description_embedding=None, text_unit_ids=['8183d9c29fa8e5548d05a25385bd5469'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='62c65bbae33c4ee9a21b61f6f454c4b4', short_id='93', source='MR GOH', target='STATUS OF THE OFFICE', weight=1.0, description='Mr Goh plans to utilize the status of the office for fundraising', description_embedding=None, text_unit_ids=['8183d9c29fa8e5548d05a25385bd5469'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='30b7034c4468473f98ee18d00ee73b33', short_id='94', source='MR GOH', target='S$1BILLION', weight=1.0, description='Mr Goh aims to raise S$1 billion for welfare organizations and small charities', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='00f78b85e5b84999a810e311e540037b', short_id='95', source='MR GOH', target='MENTORS', weight=1.0, description='Mr Goh wants to bring together a group of mentors in different disciplines', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='3e460d9f011d4b0b9ccaae7b6a5202de', short_id='96', source='MR GOH', target='YOUNG ENTREPRENEURS', weight=1.0, description='Mr Goh aims to mentor and nurture young entrepreneurs', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='9d98dece22eb401aa1a5ce9c88c603f0', short_id='97', source='MR GOH', target='CAMPAIGN MATERIALS', weight=1.0, description='Mr Goh emphasizes the need to prepare campaign materials', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='81446ea789b24eaf9eab02dc07c3d984', short_id='98', source='MR GOH', target='CERTIFICATE OF ELIGIBILITY', weight=2.0, description='MR GOH is a candidate who is actively preparing campaign materials without waiting for the CERTIFICATE OF ELIGIBILITY, which he needs in order to participate in the upcoming election.', description_embedding=None, text_unit_ids=['0d9dfafad762b3663c21595e561fbd5e', '6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 42}),
#  Relationship(id='79f4b1c1b2be4cf7aa828846e20a4eb6', short_id='99', source='MR GOH', target='RISK', weight=1.0, description='Mr Goh mentions the concept of taking risks in entrepreneurship', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='de04830d6e414fd5b39a9e90769d9452', short_id='100', source='MR GOH', target='CONFIDENCE', weight=1.0, description='Mr Goh emphasizes the importance of having confidence in oneself', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='69db426b97714835bf4937180774787a', short_id='101', source='MR GOH', target='PREPARATION', weight=1.0, description='Mr Goh advises not to wait and to be prepared for the campaign', description_embedding=None, text_unit_ids=['6dcec8175bfc24d7ade847694089fa12'], document_ids=None, attributes={'rank': 27}),
#  Relationship(id='9c7bc862339d4a5bb21ee5154d9b33bb', short_id='102', source='MR GOH', target='COMMUNITY CERTIFICATE', weight=1.0, description='Mr Goh needs a community certificate for the election', description_embedding=None, text_unit_ids=['0d9dfafad762b3663c21595e561fbd5e'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='17bad53a0ebe4569839e5e151ff78593', short_id='103', source='PEOPLES ACTION PARTY', target='SPEAKER OF PARLIAMENT', weight=1.0, description='PAP MPs disagreed with the motion regarding the Speaker of Parliament', description_embedding=None, text_unit_ids=['79e27c971d70eb268ac15d23bcfea652'], document_ids=None, attributes={'rank': 8}),
#  Relationship(id='53d98f08e7c74158b7318357b6c660b3', short_id='104', source='CABINET MINISTER', target='THARMAN', weight=1.0, description='Tharman was a Cabinet Minister for more than two decades', description_embedding=None, text_unit_ids=['764b4d847c0addcd56ded87b58d8ddee'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='cd601f77419c403889aadeee591915b5', short_id='105', source='GOVERNMENT', target='MR THARMAN', weight=1.0, description='Mr Tharman will retire from all his positions in government', description_embedding=None, text_unit_ids=['980494d0450ecadd7ac7fa605f8ddf52'], document_ids=None, attributes={'rank': 32}),
#  Relationship(id='0f564ebd53e940fba9d16674ac7bc038', short_id='106', source='GOVERNMENT', target='RESERVES', weight=1.0, description='The government is discussing using reserves for pandemic support', description_embedding=None, text_unit_ids=['f0e7f7ffaeb43ee816b649c53380c58c'], document_ids=None, attributes={'rank': 26}),
#  Relationship(id='7deb75816e4f473480e0c79ae99b5bf4', short_id='107', source='GOVERNMENT', target='PAST RESERVES', weight=1.0, description='The government may draw down past reserves for exceptional situations', description_embedding=None, text_unit_ids=['2847a743024ae3a6c6104432992ba00d'], document_ids=None, attributes={'rank': 14}),
#  Relationship(id='7f85b181f1184f77aeb3ea2155cf4027', short_id='108', source='GOVERNMENT', target='ASSOC PROF LIM', weight=1.0, description='Assoc Prof Lim expresses views on government policies', description_embedding=None, text_unit_ids=['685049748c0c45ce8501deb25aeca4a3'], document_ids=None, attributes={'rank': 13}),
#  Relationship(id='d148b2b2033048618f1a090a492a40a5', short_id='109', source='GOVERNMENT', target='NG', weight=1.0, description='Mr Ng mentions not owing any political party any favors', description_embedding=None, text_unit_ids=['6c53b4db7ae57770eb8a29804880eb5b'], document_ids=None, attributes={'rank': 68}),
#  Relationship(id='4d839a10353e4144a26563b0966721d5', short_id='110', source='GOVERNMENT', target='THARMAN', weight=1.0, description="Mr Tharman's remarks are related to government policies impacting Singaporeans", description_embedding=None, text_unit_ids=['6c53b4db7ae57770eb8a29804880eb5b'], document_ids=None, attributes={'rank': 38}),
#  Relationship(id='521a862bb196488389f17c0b0f4b6f4d', short_id='111', source='GOVERNMENT', target='SINGAPOREANS', weight=2.0, description='The GOVERNMENT in Singapore implements policies that impact all SINGAPOREANS. The relationship between the government and Singaporeans is significant, as government decisions have a direct effect on the lives of the Singaporean population. The timestamp of these interactions is crucial for understanding the context in which policies are implemented and how they affect the community.', description_embedding=None, text_unit_ids=['6c53b4db7ae57770eb8a29804880eb5b', 'e593dbf772aecd32967f6efc54be885f'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='22ea3328fb6343f4ad2862495ea27640', short_id='112', source='GOVERNMENT', target='ELECTED PRESIDENCY', weight=1.0, description='The elected presidency serves as a check and balance to the Government', description_embedding=None, text_unit_ids=['6c53b4db7ae57770eb8a29804880eb5b'], document_ids=None, attributes={'rank': 21}),
#  Relationship(id='3f9a2a2c1c0a424e8b4980ea9d48bdbe', short_id='113', source='GOVERNMENT', target='CHECK AND BALANCE', weight=1.0, description='Check and balance is a mechanism against corruption in the government', description_embedding=None, text_unit_ids=['6a00a1c8533581d4f636a985162da8ae'], document_ids=None, attributes={'rank': 12}),
#  Relationship(id='aa2ec452728a4703ae1bdabe85b6c079', short_id='114', source='GOVERNMENT', target='CORRUPTION', weight=1.0, description='Government needs check and balance to prevent corruption', description_embedding=None, text_unit_ids=['6a00a1c8533581d4f636a985162da8ae'], document_ids=None, attributes={'rank': 12}),
#  Relationship(id='c5ddb31e0a9c4b2683e4631283dd505b', short_id='115', source='MR THARMAN', target='PRESIDENT', weight=1.0, description='Mr Tharman is a potential candidate for the Presidency', description_embedding=None, text_unit_ids=['e258a2f6f582f26433e7ee6ab285a0bd'], document_ids=None, attributes={'rank': 34}),
#  Relationship(id='07d8eeb549044ac88d2e788c146a0ef1', short_id='116', source='MR THARMAN', target="PEOPLE'S ACTION PARTY", weight=2.0, description="Mr Tharman will resign from the People's Action Party", description_embedding=None, text_unit_ids=['980494d0450ecadd7ac7fa605f8ddf52', 'e258a2f6f582f26433e7ee6ab285a0bd'], document_ids=None, attributes={'rank': 23}),
#  Relationship(id='47df2815030c4f1c99facd5cf2482526', short_id='117', source='MR THARMAN', target='PE 2023', weight=1.0, description='Mr Tharman is intending to run for President in PE 2023', description_embedding=None, text_unit_ids=['980494d0450ecadd7ac7fa605f8ddf52'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='ae521508bdc244f99c4fce4ab5214c79', short_id='118', source='MR THARMAN', target='DEPUTY PRIME MINISTER', weight=1.0, description='Mr Tharman is a former Deputy Prime Minister', description_embedding=None, text_unit_ids=['980494d0450ecadd7ac7fa605f8ddf52'], document_ids=None, attributes={'rank': 23}),
#  Relationship(id='6315b4bf135c40358823ed7e4e4060e2', short_id='119', source='MR THARMAN', target='REPORTERS', weight=1.0, description='Mr Tharman spoke to reporters regarding his intentions', description_embedding=None, text_unit_ids=['980494d0450ecadd7ac7fa605f8ddf52'], document_ids=None, attributes={'rank': 29}),
#  Relationship(id='33905debec1a45ecae1c65daac1d854c', short_id='120', source='MR THARMAN', target='COMMITTEE', weight=1.0, description='The committee is evaluating Mr Tharman for a specific position', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 34}),
#  Relationship(id='bfbe904780fe47daad1a04126b12923c', short_id='121', source='MR THARMAN', target='PUBLIC SECTOR SERVICE TRACK', weight=1.0, description='Mr Tharman is being evaluated under the public sector service track', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='0614f00e932c4cd0b53928053811ebc1', short_id='122', source='MR THARMAN', target='INTEGRITY', weight=1.0, description='Mr Tharman is evaluated to have integrity', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 26}),
#  Relationship(id='9ef487dd0b574b108c60a56d6a2f146c', short_id='123', source='MR THARMAN', target='GOOD CHARACTER', weight=1.0, description='Mr Tharman is evaluated to have good character', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 23}),
#  Relationship(id='4067269e7f6943cdbc299ce02b7eadbd', short_id='124', source='MR THARMAN', target='REPUTATION', weight=1.0, description='Mr Tharman is evaluated to have a good reputation', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 26}),
#  Relationship(id='094a736ba43c4da48c556437f47f88d1', short_id='125', source='MR THARMAN', target='ARTICLE 19(3)(A)', weight=1.0, description='Mr Tharman meets the public sector service requirement under Article 19(3)(a)', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='563c2af32bb3476299e9b24a646097ab', short_id='126', source='MR THARMAN', target='MINISTER', weight=1.0, description='Mr Tharman held office as a minister for a period of three or more years', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='d59b49eb94ce442d89907e90c5d3a44e', short_id='127', source='MR THARMAN', target='JURONG GROUP REPRESENTATION CONSTITUENCY', weight=1.0, description='Mr Tharman won his seat in Jurong Group Representation Constituency in four General Elections', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='8ea7cef407df48098046551e303e1c64', short_id='128', source='MR THARMAN', target='GENERAL ELECTIONS', weight=1.0, description='Mr Tharman participated in General Elections', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='186e60d2176547bf84e5bf87bd16bb40', short_id='129', source='MR THARMAN', target='MAY 2019', weight=1.0, description='Mr Tharman held the position of senior minister from May 2019', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='e65017091c8d4c7daa45b6c8414e0465', short_id='130', source='MR THARMAN', target='SENIOR MINISTER', weight=1.0, description='Mr Tharman held the position of senior minister', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='a0f326b9597b49dda6563e9208316117', short_id='131', source='MR THARMAN', target='COORDINATING MINISTER FOR SOCIAL POLICIES', weight=1.0, description='Mr Tharman held the position of Coordinating Minister for Social Policies', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 22}),
#  Relationship(id='bff3db70f9af4f2c87a93df48ecbb6bc', short_id='132', source='MR THARMAN', target='MONETARY AUTHORITY OF SINGAPORE', weight=1.0, description='Mr Tharman chaired the Monetary Authority of Singapore', description_embedding=None, text_unit_ids=['1e5e641860f609e17997785ef15577b4'], document_ids=None, attributes={'rank': 24}),
#  Relationship(id='bf91f36307cb43e1ab1e967cb3ba8274', short_id='133', source='MR THARMAN', target='MR NG', weight=3.0, description="Mr Ng and Mr Tharman have differences of opinion, but Mr Ng acknowledges Mr Tharman's mandate from Singaporeans.", description_embedding=None, text_unit_ids=['23bdaf475083cb17fd0392ad0717475f', '2d7132d240dba2916e7eef851577ff4c'], document_ids=None, attributes={'rank': 49}),
#  Relationship(id='cd58a8740ba54d86a77db9bb9544ef0d', short_id='134', source='PRESIDENT', target='CT', weight=1.0, description='CT believes Mr Tharman will be a great President for Singapore', description_embedding=None, text_unit_ids=['7a135689160d781a60b2b66f63b1f846'], document_ids=None, attributes={'rank': 16}),
#  Relationship(id='e96d3475d43b42a781b297ae7e650afe', short_id='135', source='PRESIDENT', target='THARMAN', weight=2.0, description='The data suggests that Tharman is aiming to become the President of Singapore and is believed to be a great candidate for the position. The timestamp of this information is not provided.', description_embedding=None, text_unit_ids=['13caff68638e68546b735712429e6000', 'afafeb7bc3059dadb6df9621d2287252'], document_ids=None, attributes={'rank': 40}),
# ...
#  Relationship(id='7c8c464ed7044a7896adfeb35f58a04d', short_id='595', source='SPEAKERS', target='NAIR', weight=1.0, description="Nair presented an amended motion regarding the Speaker's independence", description_embedding=None, text_unit_ids=['810644e585d3c0e509315bb0f9412f85'], document_ids=None, attributes={'rank': 13}),
#  Relationship(id='5fa2eec73bec481b85eba22ea7a2a927', short_id='596', source='SPEAKERS', target='INDRANEE RAJAH', weight=1.0, description='Indranee Rajah is discussing the role of the Speaker in parliament', description_embedding=None, text_unit_ids=['1d19366caec16a272de63c3978147c34'], document_ids=None, attributes={'rank': 12}),
#  Relationship(id='e6aa5eedca984c56b5fa5e179127951d', short_id='597', source='SPEAKERS', target='LIM BIOW CHUAN', weight=1.0, description='Lim Biow Chuan is providing an example of Speakers resigning from political parties', description_embedding=None, text_unit_ids=['1d19366caec16a272de63c3978147c34'], document_ids=None, attributes={'rank': 11}),
#  Relationship(id='1c4bd4ba4ef64a93acd55faa8fd97ca9', short_id='598', source='SPEAKERS', target='UK', weight=1.0, description='The UK is used as an example of Speakers resigning from political parties', description_embedding=None, text_unit_ids=['1d19366caec16a272de63c3978147c34'], document_ids=None, attributes={'rank': 11}),
#  Relationship(id='5b85c70d578c4d67b5cb4743552bd559', short_id='599', source='SPEAKERS', target='NMPS', weight=3.0, description='The NMPs (Non-Member of Parliament) are being suggested as potential Speakers, despite some opinions stating that they may not have sufficient experience for the role. There is a debate surrounding the suitability of NMPs to take on the position of Speakers within the political domain.', description_embedding=None, text_unit_ids=['685049748c0c45ce8501deb25aeca4a3', 'c46d8d5b320daa32dd619e668c67c0c1'], document_ids=None, attributes={'rank': 12}),
#  Relationship(id='956113fb770840c38bce65bb5832f988', short_id='600', source='SPEAKERS', target='THOMAS', weight=1.0, description='Thomas supports the motion regarding the Speaker', description_embedding=None, text_unit_ids=['c46d8d5b320daa32dd619e668c67c0c1'], document_ids=None, attributes={'rank': 12}),
#  Relationship(id='785bb55e79954b0c84a4a53cd7f0b454', short_id='601', source='NAIR', target='SPEAKER', weight=1.0, description="Nair argues that a Speaker's political affiliation does not affect independence", description_embedding=None, text_unit_ids=['4c20c80036786c24fde5f4853266093a'], document_ids=None, attributes={'rank': 15}),
#  Relationship(id='1239281fd3774b91a99358c9c1e6ee1c', short_id='602', source='NAIR', target='THOMAS', weight=1.0, description='Thomas supports the motion as amended by Nair', description_embedding=None, text_unit_ids=['c46d8d5b320daa32dd619e668c67c0c1'], document_ids=None, attributes={'rank': 5}),
#  Relationship(id='32b29a842b224f4c99fa1d5c764efc9a', short_id='603', source='CORE MEMBER', target='IMPARTIAL PRESIDING OFFICER', weight=1.0, description='A core member is expected to be impartial in the role of a presiding officer', description_embedding=None, text_unit_ids=['4c20c80036786c24fde5f4853266093a'], document_ids=None, attributes={'rank': 3}),
#  Relationship(id='f5ae7dc11fd64822a3a15e7d3839031a', short_id='604', source='RULING PARTY', target='SPEAKER', weight=1.0, description="The Speaker's affiliation with the ruling party may impact impartiality", description_embedding=None, text_unit_ids=['4c20c80036786c24fde5f4853266093a'], document_ids=None, attributes={'rank': 13}),
#  Relationship(id='e1e254e67719488894eaa3553112a8cf', short_id='605', source='SPEAKER', target='INDEPENDENCE', weight=1.0, description="The Speaker's independence is crucial for impartiality", description_embedding=None, text_unit_ids=['4c20c80036786c24fde5f4853266093a'], document_ids=None, attributes={'rank': 13}),
#  Relationship(id='ebdd79169d7d41b99faf09b039a66204', short_id='606', source='SPEAKER', target='POLITICAL STRATEGY', weight=1.0, description="The Speaker may be privy to the ruling party's political strategy", description_embedding=None, text_unit_ids=['4c20c80036786c24fde5f4853266093a'], document_ids=None, attributes={'rank': 13}),
#  Relationship(id='e036534e17b24dd2895167a20873230f', short_id='607', source='SPEAKER', target='MP LIM BIOW CHUAN', weight=1.0, description='MP Lim Biow Chuan uses the UK as an example of Speaker independence', description_embedding=None, text_unit_ids=['4c20c80036786c24fde5f4853266093a'], document_ids=None, attributes={'rank': 13}),
#  Relationship(id='a00bc5e4be634b08b1f084b6a07abafd', short_id='608', source='SPEAKER', target='INDRANEE RAJAH', weight=1.0, description='Indranee Rajah emphasizes the importance of a non-partisan Speaker', description_embedding=None, text_unit_ids=['4c20c80036786c24fde5f4853266093a'], document_ids=None, attributes={'rank': 14}),
#  Relationship(id='ce8241c964724429bb361b7b53867007', short_id='609', source='SPEAKER', target='MAJORITY PARTY', weight=1.0, description='The majority party appoints the Speaker', description_embedding=None, text_unit_ids=['b6c4b7ce9bf36c2fa4228641ac213f6b'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='61cd7f168f7f44d6a23415e9497f1e65', short_id='610', source='SPEAKER', target='POLITICAL PARTY', weight=1.0, description='The Speaker should not be affiliated with a political party', description_embedding=None, text_unit_ids=['97c126fdfffd546b4dccdce902f688f3'], document_ids=None, attributes={'rank': 17}),
#  Relationship(id='3be77a7b57e34c55acc1f1dfbc64ee10', short_id='611', source='MS INDRANEE', target='MAJORITY PARTY', weight=1.0, description='Ms Indranee discusses the concept of the majority party in elections', description_embedding=None, text_unit_ids=['b6c4b7ce9bf36c2fa4228641ac213f6b'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='751c564f8ff6444d9d4c8de4a677e655', short_id='612', source='ASSOCIATE PROFESSOR LIM', target='POLICIES', weight=1.0, description='Assoc Prof Lim discusses the need for active debate in policymaking', description_embedding=None, text_unit_ids=['b6c4b7ce9bf36c2fa4228641ac213f6b'], document_ids=None, attributes={'rank': 5}),
#  Relationship(id='96963c158fb64680bded290f442ff9aa', short_id='613', source='ASSOCIATE PROFESSOR LIM', target='MINORITY', weight=1.0, description='Assoc Prof Lim speaks up for the minority group', description_embedding=None, text_unit_ids=['b6c4b7ce9bf36c2fa4228641ac213f6b'], document_ids=None, attributes={'rank': 5}),
#  Relationship(id='bdbfbde5dd244447a2a0674b30ae3e8f', short_id='614', source='ASSOCIATE PROFESSOR LIM', target='COMPETITION', weight=1.0, description='Assoc Prof Lim advocates for greater competition in politics', description_embedding=None, text_unit_ids=['b6c4b7ce9bf36c2fa4228641ac213f6b'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='f970bfe31db74929abff6ea38e5d18e6', short_id='615', source='MINORITY', target='ASSOC PROF LIM', weight=1.0, description='Assoc Prof Lim speaks up for the minority group', description_embedding=None, text_unit_ids=['685049748c0c45ce8501deb25aeca4a3'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='6f0c2a8b79e6406a8ab7a20864ae2ce2', short_id='616', source='MR NAIRS', target='MPS', weight=1.0, description='MPs support Mr Nairs amended motion', description_embedding=None, text_unit_ids=['685049748c0c45ce8501deb25aeca4a3'], document_ids=None, attributes={'rank': 3}),
#  Relationship(id='7b09e60e33f44ffdab9c656c5b9c1d50', short_id='617', source='NOMINATED MP RAJ JOSHUA THOMAS', target='NMPS', weight=1.0, description='Nominated MP Raj Joshua Thomas mentions NMPs in his speech', description_embedding=None, text_unit_ids=['685049748c0c45ce8501deb25aeca4a3'], document_ids=None, attributes={'rank': 3}),
#  Relationship(id='8b7beab7c0a143aea7bffc31df7528d5', short_id='618', source='POLITICAL PARTY', target='ELECTED PRESIDENCY', weight=1.0, description='The President must not be affiliated with a political party', description_embedding=None, text_unit_ids=['e593dbf772aecd32967f6efc54be885f'], document_ids=None, attributes={'rank': 15}),
#  Relationship(id='d03eb34a0612420680555ab9f10d03d5', short_id='619', source='CANDIDATE', target='UNDERDOG', weight=1.0, description='An underdog is often perceived as having lower chances of winning', description_embedding=None, text_unit_ids=['2a05612f0748db484b33bfabd38197f3'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='b066746cdff7440c8a3591f0c098201d', short_id='620', source='ELECTED PRESIDENCY', target='GENERAL ELECTION', weight=1.0, description='The Elected Presidency and General Election should not overlap in representation', description_embedding=None, text_unit_ids=['e593dbf772aecd32967f6efc54be885f'], document_ids=None, attributes={'rank': 11}),
#  Relationship(id='1e2eded8ef7b4b458c33fbc2d36c4380', short_id='621', source='ELECTED PRESIDENCY', target='SYSTEM OF GOVERNANCE', weight=1.0, description='Elected presidency is part of the system of governance in Singapore', description_embedding=None, text_unit_ids=['6a00a1c8533581d4f636a985162da8ae'], document_ids=None, attributes={'rank': 11}),
#  Relationship(id='c59e3e931b0f4cf888c2eb70857ee753', short_id='622', source='ELECTED PRESIDENCY', target='REFORM', weight=1.0, description='Reform is needed in the elected presidency system', description_embedding=None, text_unit_ids=['6a00a1c8533581d4f636a985162da8ae'], document_ids=None, attributes={'rank': 11}),
#  Relationship(id='305b80bb4df5488b8a34129daeeae0c7', short_id='623', source='ELECTED PRESIDENCY', target='INFLUENCES AND AGENDAS', weight=1.0, description='Influences and agendas should not affect the elected presidency', description_embedding=None, text_unit_ids=['6a00a1c8533581d4f636a985162da8ae'], document_ids=None, attributes={'rank': 11}),
#  Relationship(id='66fa0de756da440bad8da583306410c4', short_id='624', source='BOOING', target='VOCAL MINORITY', weight=1.0, description='Booing came from a vocal minority', description_embedding=None, text_unit_ids=['2a05612f0748db484b33bfabd38197f3'], document_ids=None, attributes={'rank': 2}),
#  Relationship(id='d1e9c550a0e74c48ae81c319f26ccafc', short_id='625', source='IMDA', target='BROADCAST', weight=1.0, description='IMDA responsible for the conduct of election broadcasts', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 10}),
#  Relationship(id='3730b5d759ba4fd28a54af0a02151f09', short_id='626', source='IMDA', target='SINGAPORE CONSTITUTION', weight=1.0, description='IMDA ensures broadcasts align with the Singapore Constitution', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 10}),
#  Relationship(id='82b7f7c27e2348f880c94ffb80942de7', short_id='627', source='IMDA', target='POLITICAL OBSERVER', weight=1.0, description='Political observer comments on the actions of IMDA', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 8}),
#  Relationship(id='0980c4f558654466b4d691d0cb7ce16d', short_id='628', source='IMDA', target='EUGENE TAN', weight=1.0, description='Eugene Tan comments on the actions of IMDA', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 9}),
#  Relationship(id='f1e47cf5daa441649c3474c3339bb704', short_id='629', source='INVESTMENT STRATEGIES', target='STATEMENTS', weight=1.0, description='Statements provide guidance on investment strategies', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='0964dcfbff934c92af8961155673ac7f', short_id='630', source='STATEMENTS', target='VISION', weight=1.0, description="Statements cover the candidate's vision for influencing government policies", description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='51b82bcdffe04056bad1c082c3830047', short_id='631', source='VISION', target="PRESIDENT'S OFFICE", weight=1.0, description="Candidate's vision aims to influence government policies from the President's office", description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='c62bb148852b49a98e2779ca23a0919d', short_id='632', source="PRESIDENT'S OFFICE", target='GOVERNMENT POLICIES', weight=1.0, description="Government policies influenced from the President's office", description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='72b5a0c357c24b739084d501b9354bc1', short_id='633', source='GOVERNMENT POLICIES', target='OPINIONS', weight=1.0, description='Opinions offered by the elected president on government policies', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='c827b62ebf134e55a3ccf0b63f976870', short_id='634', source='ELECTED PRESIDENT', target='OPINIONS', weight=1.0, description='Elected president can offer opinions on government policies', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 4}),
#  Relationship(id='b51ef388758845e880e736309ae791e3', short_id='635', source='BROADCAST', target='EUGENE TAN', weight=1.0, description="Eugene Tan comments on Mr. Tan's misrepresentation in the broadcast", description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 5}),
#  Relationship(id='0a841cd4b6664423b033f22e3a80f33c', short_id='636', source='BROADCAST', target='SINGAPORE CONSTITUTION', weight=1.0, description='Broadcast presents a vision of the presidency that aligns with the Singapore Constitution', description_embedding=None, text_unit_ids=['998aeb23abdb5d78a5781d3f6750bfb1'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='16911c51c65b42f8a2d04c05f45b2c58', short_id='637', source='TEXT DOCUMENT', target='ENTITIES', weight=1.0, description='The text document contains various identified entities', description_embedding=None, text_unit_ids=['33aba9b9b3839b41e12291338e195321'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='fc3f77f29574410d991a2aa333950bf6', short_id='638', source='TEXT DOCUMENT', target='RELATIONSHIPS', weight=1.0, description='The text document contains relationships among the identified entities', description_embedding=None, text_unit_ids=['33aba9b9b3839b41e12291338e195321'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='4f847eb72cbe48678d5634dcf93fc0e2', short_id='639', source='TEXT DOCUMENT', target='TIMESTAMP', weight=1.0, description='The text document has a specific timestamp indicating its publish date', description_embedding=None, text_unit_ids=['33aba9b9b3839b41e12291338e195321'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='829e64159ae04301982e88e93a2f0e49', short_id='640', source='TEXT DOCUMENT', target='CNA_3734106_IMG3', weight=1.0, description='The text document contains a specific identifier CNA_3734106_IMG3', description_embedding=None, text_unit_ids=['33aba9b9b3839b41e12291338e195321'], document_ids=None, attributes={'rank': 6}),
#  Relationship(id='cf37d3d4bc154f65b3d79c831c587763', short_id='641', source='TEXT DOCUMENT', target='CNA_3734106_IMG4', weight=1.0, description='The text document contains a specific identifier CNA_3734106_IMG4', description_embedding=None, text_unit_ids=['33aba9b9b3839b41e12291338e195321'], document_ids=None, attributes={'rank': 6})]

# %%
# %pip install yfiles_jupyter_graphs --quiet
from yfiles_jupyter_graphs import GraphWidget


# converts the entities dataframe to a list of dicts for yfiles-jupyter-graphs
def convert_entities_to_dicts(df):
    """Convert the entities dataframe to a list of dicts for yfiles-jupyter-graphs."""
    nodes_dict = {}
    for _, row in df.iterrows():
        # Create a dictionary for each row and collect unique nodes
        node_id = row["title"]
        if node_id not in nodes_dict:
            nodes_dict[node_id] = {
                "id": node_id,
                "properties": row.to_dict(),
            }
    return list(nodes_dict.values())


# converts the relationships dataframe to a list of dicts for yfiles-jupyter-graphs
def convert_relationships_to_dicts(df):
    """Convert the relationships dataframe to a list of dicts for yfiles-jupyter-graphs."""
    relationships = []
    for _, row in df.iterrows():
        # Create a dictionary for each row
        relationships.append({
            "start": row["source"],
            "end": row["target"],
            "properties": row.to_dict(),
        })
    return relationships


w = GraphWidget()
w.directed = True
w.nodes = convert_entities_to_dicts(entity_df)
w.edges = convert_relationships_to_dicts(relationship_df)

# %%
# show title on the node
w.node_label_mapping = "title"


# map community to a color
def community_to_color(community):
    """Map a community to a color."""
    colors = [
        "crimson",
        "darkorange",
        "indigo",
        "cornflowerblue",
        "cyan",
        "teal",
        "green",
    ]
    return (
        colors[int(community) % len(colors)] if community is not None else "lightgray"
    )


def edge_to_source_community(edge):
    """Get the community of the source node of an edge."""
    source_node = next(
        (entry for entry in w.nodes if entry["properties"]["title"] == edge["start"]),
        None,
    )
    source_node_community = source_node["properties"]["community"]
    return source_node_community if source_node_community is not None else None


w.node_color_mapping = lambda node: community_to_color(node["properties"]["community"])
w.edge_color_mapping = lambda edge: community_to_color(edge_to_source_community(edge))
# map size data to a reasonable factor
w.node_scale_factor_mapping = lambda node: 0.5 + node["properties"]["size"] * 1.5 / 20
# use weight for edge thickness
w.edge_thickness_factor_mapping = "weight"

# %%
# # Use the circular layout for this visualization. For larger graphs, the default organic layout is often preferrable.
w.circular_layout()

# %%
# display(w)

# %% [markdown]
# ###
# Visualizing the result context of `graphrag` queries

# %%
# setup (see also ../../local_search.ipynb)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)

description_embedding_store = LanceDBVectorStore(
    collection_name="entity_description_embeddings",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)
entity_description_embeddings = store_entity_semantic_embeddings(
    entities=entities, vectorstore=description_embedding_store
)
# covariate_df = pd.read_parquet(f"{INPUT_DIR}/{COVARIATE_TABLE}.parquet")
# claims = read_indexer_covariates(covariate_df)
# covariates = {"claims": claims}
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

api_key = "" 
llm_model = "llama3"
embedding_model = "text-embedding-3-small"

llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_type=OpenaiApiType.OpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

text_embedder = OpenAIEmbedding(
    api_key=api_key,
    api_base=None,
    api_type=OpenaiApiType.OpenAI,
    model=embedding_model,
    deployment_name=embedding_model,
    max_retries=20,
)

context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    # covariates=covariates,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,  # if the vectorstore uses entity title as ids, set this to EntityVectorStoreKey.TITLE
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

local_context_params = {
    "text_unit_prop": 0.5,
    "community_prop": 0.1,
    "conversation_history_max_turns": 5,
    "conversation_history_user_turns_only": True,
    "top_k_mapped_entities": 10,
    "top_k_relationships": 10,
    "include_entity_rank": True,
    "include_relationship_weight": True,
    "include_community_rank": False,
    "return_candidate_context": False,
    "embedding_vectorstore_key": EntityVectorStoreKey.ID,  # set this to EntityVectorStoreKey.TITLE if the vectorstore uses entity title as ids
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
}

llm_params = {
    "max_tokens": 2_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000=1500)
    "temperature": 0.0,
}

search_engine = LocalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %% [markdown]
# ## Run local search on sample queries

# %%
result = await search_engine.asearch("Who are the candidates for the 2023 presidential elections")
print(result.response)
# Out:
# In the upcoming 2023 Presidential Election in Singapore, several candidates have emerged to compete for the position of President. Among the notable candidates are Mr. Ng Kok Song, Mr. Tan Kin Lian, Mr. Tharman Shanmugaratnam, and Mr. George Goh [Data: Entities (105, 15, 17, 48)]. Each candidate brings a unique background and perspective to the election, shaping the dynamics of the political landscape leading up to the election.
#
# Mr. Ng Kok Song, a former GIC investment officer, has actively participated in the election campaign, emphasizing his commitment to divesting his stake in Avanda Investment Management to ensure his independence if elected [Data: Relationships (324, 316, 320); Sources (38)]. On the other hand, Mr. Tan Kin Lian has faced scrutiny over his social media posts, sparking debates on the acceptability of his behavior as a presidential candidate [Data: Sources (5, 14, 89)]. Additionally, Mr. Tharman Shanmugaratnam, a former Senior Minister, has positioned himself as a candidate focused on independence and the role of the President in influencing government policies [Data: Relationships (42, 47, 53); Sources (4, 22)]. Lastly, Mr. George Goh, a businessman, has outlined his campaign platform centered on transparency, philanthropy, and mentorship, highlighting his vision for an open and inclusive presidency [Data: Sources (51, 58, 89)].
#
# The interactions and debates among these candidates reflect the diverse perspectives and approaches they bring to the presidential race. As the election unfolds, the candidates' strategies, messages, and interactions with the public will continue to shape the narrative and outcomes of the 2023 Presidential Election in Singapore.

# %% [markdown]
# ## Inspecting the context data used to generate the response

# %%
result.context_data["entities"].head()
# Out:
#     id                   entity  \
# 0   71  PRESIDENTIAL CANDIDATES
# 1   92               CANDIDATES
# 2   33                  PE 2023
# 3  461       PRESIDENTIAL FORUM
# 4  101                APPLICANT
#
#                                          description number of relationships  \
# 0  Presidential candidates are individuals runnin...                       2
# 1  The "Candidates" are individuals who are activ...                       7
# 2  PE 2023 refers to the upcoming Presidential El...                       8
# 3  Presidential forum is an event where candidate...                       1
# 4  Applicant refers to individuals applying for c...                       5
#
#    in_context
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
result.context_data["relationships"].head()
# print(len(result.context_data["relationships"]))
# Out:
#     id                      source       target  \
# 0   86                      MR GOH  NG KOK SONG
# 1  167                     PE 2023  NG KOK SONG
# 2   82                      MR GOH       MR TAN
# 3  165                     PE 2023   CANDIDATES
# 4  162  CERTIFICATE OF ELIGIBILITY  NG KOK SONG
#
#                                          description weight rank links  \
# 0  Both Mr Goh and Ng Kok Song are candidates and...    2.0   59     2
# 1  Ng Kok Song is one of the candidates for the P...    2.0   41     2
# 2  Mr Goh and Mr Tan are both candidates and pres...    2.0   40     1
# 3  Candidates are participating in the Presidenti...    2.0   15     1
# 4  Ng Kok Song mentions his application for a cer...    1.0   49     5
#
#    in_context
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
result.context_data["reports"].head()
# Out:
#    id                                           title  \
# 0  15  Mr. Ng and the Presidential Election Community
#
#                                              content
# 0  # Mr. Ng and the Presidential Election Communi...

# %%
result.context_data["sources"].head()
# Out:
#    id                                               text
# 0  84   have time to argue about that" and that he wo...
# 1  10   cent of the voters.\n\nHer contacts on Linked...
# 2  17   applications on Thursday evening, ELD said th...
# 3  21                                        5526_img1\n
# 4  15                                            _img1\n

# %% [markdown]
# ## Visualizing the result context as graph

# %%
"""
Helper function to visualize the result context with `yfiles-jupyter-graphs`.

The dataframes are converted into supported nodes and relationships lists and then passed to yfiles-jupyter-graphs.
Additionally, some values are mapped to visualization properties.
"""
def show_graph(result):
    """Visualize the result context with yfiles-jupyter-graphs."""
    from yfiles_jupyter_graphs import GraphWidget

    if (
        "entities" not in result.context_data
        or "relationships" not in result.context_data
    ):
        msg = "The passed results do not contain 'entities' or 'relationships'"
        raise ValueError(msg)

    # converts the entities dataframe to a list of dicts for yfiles-jupyter-graphs
    def convert_entities_to_dicts(df):
        """Convert the entities dataframe to a list of dicts for yfiles-jupyter-graphs."""
        nodes_dict = {}
        for _, row in df.iterrows():
            # Create a dictionary for each row and collect unique nodes
            node_id = row["entity"]
            if node_id not in nodes_dict:
                nodes_dict[node_id] = {
                    "id": node_id,
                    "properties": row.to_dict(),
                }
        return list(nodes_dict.values())

    # converts the relationships dataframe to a list of dicts for yfiles-jupyter-graphs
    def convert_relationships_to_dicts(df):
        """Convert the relationships dataframe to a list of dicts for yfiles-jupyter-graphs."""
        relationships = []
        for _, row in df.iterrows():
            # Create a dictionary for each row
            relationships.append({
                "start": row["source"],
                "end": row["target"],
                "properties": row.to_dict(),
            })
        return relationships

    w = GraphWidget()
    # use the converted data to visualize the graph
    w.nodes = convert_entities_to_dicts(result.context_data["entities"])
    w.edges = convert_relationships_to_dicts(result.context_data["relationships"])
    w.directed = True
    # show title on the node
    w.node_label_mapping = "entity"
    # use weight for edge thickness
    w.edge_thickness_factor_mapping = "weight"
    display(w)


show_graph(result)
# Out:
# GraphWidget(layout=Layout(height='700px', width='100%'))
